# %% [markdown]
# ## Part 1

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
import onnxruntime as rt
import onnx
from skl2onnx.common.data_types import FloatTensorType
from skl2onnx import to_onnx
from skl2onnx import convert_sklearn

from term_styling import style, fg, bg

random_state_seed = 42

# %%
# Let's load the dataset
data = pd.read_csv('data/investigation_train_large_checked.csv')

# Let's specify the features and the target
target = data['checked']
features = data.drop(columns=[ 'checked', 'Ja', 'Nee' ])
features = features.astype(np.float32)

# %%
def get_problematic_columns( data ):
    psychological_features = []
    medical_features = [ 'belemmering_hist_verslavingsproblematiek' ]
    racial_features = ['ontheffing_reden_hist_sociale_gronden']
    subjective_features = [ 'competentie_ethisch_en_integer_handelen', 'competentie_gedrevenheid_en_ambitie_tonen', 'competentie_met_druk_en_tegenslag_omgaan', 'competentie_omgaan_met_verandering_en_aanpassen',
                            'persoonlijke_eigenschappen_uitstroom_verw_vlgs_km', 'persoonlijke_eigenschappen_uitstroom_verw_vlgs_klant', 'afspraak_aantal_woorden', 'afspraak_laatstejaar_aantal_woorden',
                            'competentie_other', 'competentie_overtuigen_en_beïnvloeden'
                          ]
    age_features = ['persoon_leeftijd_bij_onderzoek']
    gender_features = ['persoon_geslacht_vrouw']
    relationship_features = []
    irrelevant_features = [ 'persoonlijke_eigenschappen_hobbies_sport' ]

    for col in data.columns:
        if 'relatie' in col:
            relationship_features.append( col )
        elif 'persoonlijke' in col:
            if '_nl_' in col or 'taal' in col:
                racial_features.append(col)
            elif '_opm' in col:
                subjective_features.append(col)
        elif 'adres_recenst' in col or 'sociaal' in col or 'taal' in col:
            racial_features.append(col)
        elif 'medische' in col or 'lichamelijke' in col:
            medical_features.append(col)
        elif 'psychische' in col:
            psychological_features.append(col)

    return {
            'psychological': psychological_features,
            'medical': medical_features,
            'racial': racial_features,
            'subjective': subjective_features,
            'gender': gender_features,
            'relationship': relationship_features,
            'age': age_features,
            'irrelevant': irrelevant_features
           }

# %% [markdown]
# ### Outlier Detection

# %%
def get_color( val, n_samples ):
    if val >= 0.15 * n_samples:
        return fg.red
    elif val >= 0.05 * n_samples:
        return fg.orange
    elif val >= 0.01 * n_samples:
        return fg.yellow
    return fg.green

# %%
def identify_outliers( x, columns, thres=2 ):
    spaces = 120
    print(f"{style.bold}Dataset Outlier Test{style.reset} - {thres} Sigma")
    print("-"*(spaces+40))
    
    n_samples = x.shape[0]
    for column in columns:
        x_min, x_max = x[column].min(), x[column].max()
        mean, std = x[column].mean(), x[column].std()
        
        #print( f"Min: {x_min}\tMax: {x_max}" )
        #print( f"Mean: {mean}\tSTD: {std}" )

        lows = x[column] <= mean - thres*std
        highs = x[column] >= mean + thres*std
        lows, highs = x[lows].shape[0], x[highs].shape[0]

        if lows > 0 or highs > 0:
            to_print = f"{column.capitalize()}:" + " "*(spaces-len(column)) + "Low:\t"
            to_print += get_color( lows, n_samples ) + f"{lows}\t" + style.reset + "High:\t"
            to_print += get_color( highs, n_samples ) + f"{highs}\t" + style.reset
                
            print( to_print )

# %% [markdown]
# #### Results

# %%
identify_outliers( features, features.columns, 2 )
# Out:
# Dataset Outlier Test - 2 Sigma
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Adres_aantal_brp_adres:                                                                                                  Low:	0	High:	7465
# Adres_aantal_verschillende_wijken:                                                                                       Low:	0	High:	9793
# Adres_aantal_verzendadres:                                                                                               Low:	0	High:	2051
# Adres_aantal_woonadres_handmatig:                                                                                        Low:	0	High:	3965
# Adres_dagen_op_adres:                                                                                                    Low:	0	High:	3618
# Adres_recentst_onderdeel_rdam:                                                                                           Low:	6426	High:	0
# Adres_recentste_buurt_groot_ijsselmonde:                                                                                 Low:	0	High:	544
# Adres_recentste_buurt_nieuwe_westen:                                                                                     Low:	0	High:	419
# Adres_recentste_buurt_oude_noorden:                                                                                      Low:	0	High:	133
# Adres_recentste_buurt_vreewijk:                                                                                          Low:	0	High:	590
# Adres_recentste_plaats_other:                                                                                            Low:	0	High:	915
# Adres_recentste_plaats_rotterdam:                                                                                        Low:	11808	High:	0
# Adres_recentste_wijk_charlois:                                                                                           Low:	0	High:	13854
# Adres_recentste_wijk_delfshaven:                                                                                         Low:	0	High:	17721
# Adres_recentste_wijk_feijenoord:                                                                                         Low:	0	High:	22520
# Adres_recentste_wijk_ijsselmonde:                                                                                        Low:	0	High:	5495
# Adres_recentste_wijk_kralingen_c:                                                                                        Low:	0	High:	5762
# Adres_recentste_wijk_noord:                                                                                              Low:	0	High:	2733
# Adres_recentste_wijk_other:                                                                                              Low:	0	High:	17386
# Adres_recentste_wijk_prins_alexa:                                                                                        Low:	0	High:	5087
# Adres_recentste_wijk_stadscentru:                                                                                        Low:	0	High:	1690
# Adres_unieke_wijk_ratio:                                                                                                 Low:	13688	High:	0
# Afspraak_aanmelding_afgesloten:                                                                                          Low:	0	High:	4936
# Afspraak_aantal_woorden:                                                                                                 Low:	0	High:	5407
# Afspraak_afgelopen_jaar_afsprakenplan:                                                                                   Low:	0	High:	2122
# Afspraak_afgelopen_jaar_monitoring_insp__wet_taaleis_na_12_mnd_n_a_v__taa04_____geen_maatregel:                          Low:	0	High:	3212
# Afspraak_afgelopen_jaar_ontheffing:                                                                                      Low:	0	High:	560
# Afspraak_afgelopen_jaar_ontheffing_taaleis:                                                                              Low:	0	High:	11243
# Afspraak_afgelopen_jaar_plan_van_aanpak:                                                                                 Low:	0	High:	3154
# Afspraak_afgelopen_jaar_signaal_voor_medewerker:                                                                         Low:	0	High:	6580
# Afspraak_afgelopen_jaar_vervolgmeting_matchbaarheid_werkzoekende_klant:                                                  Low:	0	High:	19959
# Afspraak_afgelopen_jaar_voortgang_aanmelding_en_deelname:                                                                Low:	0	High:	6592
# Afspraak_afsprakenplan:                                                                                                  Low:	0	High:	2849
# Afspraak_controle_aankondiging_maatregel:                                                                                Low:	0	High:	1354
# Afspraak_controle_verwijzing:                                                                                            Low:	0	High:	56
# Afspraak_deelname_compleet_uit_webapplicatie:                                                                            Low:	0	High:	4046
# Afspraak_galo_gesprek:                                                                                                   Low:	0	High:	4405
# Afspraak_gespr__einde_zoekt___galo_gesprek_:                                                                             Low:	0	High:	286
# Afspraak_inspanningsperiode:                                                                                             Low:	0	High:	6208
# Afspraak_laatstejaar_aantal_woorden:                                                                                     Low:	0	High:	6025
# Afspraak_laatstejaar_resultaat_ingevuld:                                                                                 Low:	0	High:	7154
# Afspraak_laatstejaar_resultaat_ingevuld_uniek:                                                                           Low:	0	High:	3606
# Afspraak_other:                                                                                                          Low:	0	High:	2825
# Afspraak_participatietrede_vervolgmeting:                                                                                Low:	0	High:	4767
# Afspraak_resultaat_ingevuld_uniek:                                                                                       Low:	2093	High:	6075
# Afspraak_signaal_van_aanbieder:                                                                                          Low:	0	High:	5701
# Afspraak_signaal_voor_medewerker:                                                                                        Low:	0	High:	6573
# Afspraak_toevoegen_inschrijving_uwvwb:                                                                                   Low:	0	High:	992
# Afspraak_vervolgmeting_matchbaarheid_werkzoekende_klant:                                                                 Low:	0	High:	568
# Afspraak_verzenden_beschikking_i_v_m__niet_voldoen_aan_wet_taaleis:                                                      Low:	0	High:	21801
# Afspraak_voortgangsgesprek:                                                                                              Low:	0	High:	5180
# Belemmering_aantal_huidig:                                                                                               Low:	0	High:	9071
# Belemmering_dagen_financiele_problemen:                                                                                  Low:	2878	High:	2893
# Belemmering_dagen_lichamelijke_problematiek:                                                                             Low:	2458	High:	3303
# Belemmering_dagen_psychische_problemen:                                                                                  Low:	4718	High:	0
# Belemmering_hist_lichamelijke_problematiek:                                                                              Low:	0	High:	3839
# Belemmering_hist_psychische_problemen:                                                                                   Low:	0	High:	3189
# Belemmering_hist_stabiele_mix__sz____dagbesteding_werk:                                                                  Low:	0	High:	9150
# Belemmering_hist_taal:                                                                                                   Low:	0	High:	9711
# Belemmering_hist_verslavingsproblematiek:                                                                                Low:	0	High:	7838
# Belemmering_niet_computervaardig:                                                                                        Low:	0	High:	1118
# Belemmering_woonsituatie:                                                                                                Low:	0	High:	695
# Beschikbaarheid_aantal_historie_afwijkend_wegens_medische_omstandigheden:                                                Low:	0	High:	2188
# Beschikbaarheid_aantal_historie_afwijkend_wegens_sociaal_maatschappelijke_situatie:                                      Low:	0	High:	942
# Beschikbaarheid_huidig_afwijkend_wegens_medische_omstandigheden:                                                         Low:	0	High:	4724
# Beschikbaarheid_recent_afwijkend_wegens_sociaal_maatschappelijke_situatie:                                               Low:	0	High:	14524
# Competentie_aansturen:                                                                                                   Low:	0	High:	233
# Competentie_analyseren:                                                                                                  Low:	0	High:	191
# Competentie_ethisch_en_integer_handelen:                                                                                 Low:	0	High:	19207
# Competentie_formuleren_en_rapporteren:                                                                                   Low:	0	High:	104
# Competentie_gedrevenheid_en_ambitie_tonen:                                                                               Low:	0	High:	21155
# Competentie_instructies_en_procedures_opvolgen:                                                                          Low:	0	High:	949
# Competentie_kwaliteit_leveren:                                                                                           Low:	0	High:	1248
# Competentie_leren:                                                                                                       Low:	0	High:	19906
# Competentie_materialen_en_middelen_inzetten:                                                                             Low:	0	High:	202
# Competentie_met_druk_en_tegenslag_omgaan:                                                                                Low:	0	High:	26
# Competentie_omgaan_met_verandering_en_aanpassen:                                                                         Low:	0	High:	24
# Competentie_onderzoeken:                                                                                                 Low:	0	High:	20055
# Competentie_op_de_behoeften_en_verwachtingen_van_de__klant__richten:                                                     Low:	0	High:	21440
# Competentie_other:                                                                                                       Low:	0	High:	7835
# Competentie_overtuigen_en_beïnvloeden:                                                                                   Low:	0	High:	224
# Competentie_plannen_en_organiseren:                                                                                      Low:	0	High:	392
# Competentie_samenwerken_en_overleggen:                                                                                   Low:	0	High:	924
# Competentie_vakdeskundigheid_toepassen:                                                                                  Low:	0	High:	2725
# Contacten_onderwerp__arbeids_motivatie:                                                                                  Low:	0	High:	5357
# Contacten_onderwerp__pre__intake:                                                                                        Low:	0	High:	4210
# Contacten_onderwerp__werk_intake:                                                                                        Low:	0	High:	9536
# Contacten_onderwerp_arbeidsdiagnose_dariuz:                                                                              Low:	0	High:	394
# Contacten_onderwerp_beoordelen_taaleis:                                                                                  Low:	0	High:	1721
# Contacten_onderwerp_boolean_financiële_situatie:                                                                         Low:	0	High:	25283
# Contacten_onderwerp_boolean_match___werk:                                                                                Low:	0	High:	6520
# Contacten_onderwerp_boolean_matching:                                                                                    Low:	0	High:	24944
# Contacten_onderwerp_boolean_motivatie:                                                                                   Low:	0	High:	1464
# Contacten_onderwerp_boolean_mutatie:                                                                                     Low:	0	High:	2737
# Contacten_onderwerp_boolean_scholing:                                                                                    Low:	0	High:	18046
# Contacten_onderwerp_boolean_sollicitatie:                                                                                Low:	0	High:	4744
# Contacten_onderwerp_contact_derden:                                                                                      Low:	0	High:	5558
# Contacten_onderwerp_contact_met_aanbieder:                                                                               Low:	0	High:	6510
# Contacten_onderwerp_diagnosegesprek:                                                                                     Low:	0	High:	2874
# Contacten_onderwerp_documenten__innemen_:                                                                                Low:	0	High:	4767
# Contacten_onderwerp_documenttype__cv_:                                                                                   Low:	0	High:	5198
# Contacten_onderwerp_documenttype__overeenkomst_:                                                                         Low:	0	High:	3284
# Contacten_onderwerp_financiële_situatie:                                                                                 Low:	0	High:	6338
# Contacten_onderwerp_groepsbijeenkomst:                                                                                   Low:	0	High:	3780
# Contacten_onderwerp_inkomen:                                                                                             Low:	0	High:	4336
# Contacten_onderwerp_inname_aanvraag:                                                                                     Low:	0	High:	24485
# Contacten_onderwerp_inspanningstoets:                                                                                    Low:	0	High:	3534
# Contacten_onderwerp_maatregel_overweging:                                                                                Low:	0	High:	6681
# Contacten_onderwerp_matching:                                                                                            Low:	0	High:	4793
# Contacten_onderwerp_mutatie:                                                                                             Low:	0	High:	86
# Contacten_onderwerp_no_show:                                                                                             Low:	0	High:	9207
# Contacten_onderwerp_overige:                                                                                             Low:	0	High:	5326
# Contacten_onderwerp_overleg_met_inkomen:                                                                                 Low:	0	High:	6671
# Contacten_onderwerp_quickscan:                                                                                           Low:	0	High:	24
# Contacten_onderwerp_scholing:                                                                                            Low:	0	High:	2143
# Contacten_onderwerp_screening:                                                                                           Low:	0	High:	1873
# Contacten_onderwerp_terugbelverzoek:                                                                                     Low:	0	High:	5541
# Contacten_onderwerp_traject:                                                                                             Low:	0	High:	4977
# Contacten_onderwerp_uitnodiging:                                                                                         Low:	0	High:	5903
# Contacten_onderwerp_vakantie:                                                                                            Low:	0	High:	15560
# Contacten_onderwerp_werkintake__niet_verschenen:                                                                         Low:	0	High:	25
# Contacten_onderwerp_ziek__of_afmelding:                                                                                  Low:	0	High:	2991
# Contacten_onderwerp_zorg:                                                                                                Low:	0	High:	6948
# Contacten_soort_afgelopenjaar_anders:                                                                                    Low:	0	High:	9710
# Contacten_soort_afgelopenjaar_document__inkomend_:                                                                       Low:	0	High:	3055
# Contacten_soort_afgelopenjaar_document__uitgaand_:                                                                       Low:	0	High:	5634
# Contacten_soort_afgelopenjaar_e_mail__inkomend_:                                                                         Low:	0	High:	4009
# Contacten_soort_afgelopenjaar_e_mail__uitgaand_:                                                                         Low:	0	High:	4826
# Contacten_soort_afgelopenjaar_gesprek:                                                                                   Low:	0	High:	5235
# Contacten_soort_afgelopenjaar_gesprek_op_locatie:                                                                        Low:	0	High:	14187
# Contacten_soort_afgelopenjaar_rapportage_rib:                                                                            Low:	0	High:	1542
# Contacten_soort_afgelopenjaar_telefoontje__inkomend_:                                                                    Low:	0	High:	5200
# Contacten_soort_afgelopenjaar_telefoontje__uitgaand_:                                                                    Low:	0	High:	6174
# Contacten_soort_anders:                                                                                                  Low:	0	High:	5096
# Contacten_soort_document__inkomend_:                                                                                     Low:	0	High:	5991
# Contacten_soort_document__uitgaand_:                                                                                     Low:	0	High:	4888
# Contacten_soort_e_mail__inkomend_:                                                                                       Low:	0	High:	6159
# Contacten_soort_e_mail__uitgaand_:                                                                                       Low:	0	High:	5088
# Contacten_soort_gesprek_op_locatie:                                                                                      Low:	0	High:	68
# Contacten_soort_groepsbijeenkomsten:                                                                                     Low:	0	High:	383
# Contacten_soort_rapportage_deelname:                                                                                     Low:	0	High:	2612
# Contacten_soort_rapportage_rib:                                                                                          Low:	0	High:	9016
# Contacten_soort_telefoontje__inkomend_:                                                                                  Low:	0	High:	6364
# Contacten_soort_telefoontje__uitgaand_:                                                                                  Low:	0	High:	5262
# Deelname_act_actueel_projecten_uniek:                                                                                    Low:	0	High:	12551
# Deelname_act_hist_projecten_niet_gestart:                                                                                Low:	0	High:	3837
# Deelname_act_reintegratieladder_ondersteunende_instrumenten:                                                             Low:	0	High:	5840
# Deelname_act_reintegratieladder_werk_re_integratie:                                                                      Low:	0	High:	6654
# Instrument_aantal_laatstejaar:                                                                                           Low:	0	High:	7554
# Instrument_ladder_historie_activering:                                                                                   Low:	0	High:	6403
# Instrument_ladder_historie_other:                                                                                        Low:	0	High:	10043
# Instrument_ladder_huidig_activering:                                                                                     Low:	0	High:	7334
# Instrument_ladder_huidig_other:                                                                                          Low:	0	High:	399
# Instrument_ladder_huidig_werk_re_integratie:                                                                             Low:	0	High:	968
# Instrument_reden_beeindiging_historie_centrale_actie_wigo4it:                                                            Low:	0	High:	10123
# Instrument_reden_beeindiging_historie_diagnose_gesteld:                                                                  Low:	0	High:	12368
# Instrument_reden_beeindiging_historie_direct_matchbaar:                                                                  Low:	0	High:	2821
# Instrument_reden_beeindiging_historie_doelstelling_bereikt__geen_uitstroom:                                              Low:	0	High:	4233
# Instrument_reden_beeindiging_historie_doelstelling_bereikt__uitstroom_naar_regulier_werk:                                Low:	0	High:	9073
# Instrument_reden_beeindiging_historie_doelstelling_bereikt__uitstroom_overig:                                            Low:	0	High:	13411
# Instrument_reden_beeindiging_historie_doelstelling_niet_bereikt__geen_uitstroom:                                         Low:	0	High:	2303
# Instrument_reden_beeindiging_historie_niet_matchbaar:                                                                    Low:	0	High:	15010
# Instrument_reden_beeindiging_historie_niet_succesvol:                                                                    Low:	0	High:	1758
# Instrument_reden_beeindiging_historie_niet_succesvol__reden_bij_werkzoekende:                                            Low:	0	High:	5580
# Instrument_reden_beeindiging_historie_op_termijn_matchbaar:                                                              Low:	0	High:	21325
# Instrument_reden_beeindiging_historie_other:                                                                             Low:	0	High:	10036
# Instrument_reden_beeindiging_historie_overdracht_naar_mo:                                                                Low:	0	High:	47
# Instrument_reden_beeindiging_historie_overdracht_naar_prematching:                                                       Low:	0	High:	11912
# Instrument_reden_beeindiging_historie_overdracht_naar_regulier_team_iwpm:                                                Low:	0	High:	2691
# Instrument_reden_beeindiging_historie_overdracht_succesvol:                                                              Low:	0	High:	186
# Instrument_reden_beeindiging_historie_succesvol:                                                                         Low:	0	High:	5582
# Instrument_reden_beeindiging_historie_succesvol__doelstelling_bereikt:                                                   Low:	0	High:	5078
# Instrument_reden_beeindiging_historie_uitval__aanbod_niet_langer_zinvol_volgens_gemeente:                                Low:	0	High:	4379
# Instrument_reden_beeindiging_historie_uitval__klant_wz__ziet_af_van_aanbod:                                              Low:	0	High:	11
# Ontheffing_dagen_hist_mean:                                                                                              Low:	79	High:	5406
# Ontheffing_dagen_hist_vanwege_uw_medische_omstandigheden:                                                                Low:	0	High:	5252
# Ontheffing_hist_ind:                                                                                                     Low:	130000	High:	130000
# Ontheffing_reden_hist_medische_gronden:                                                                                  Low:	0	High:	1803
# Ontheffing_reden_hist_other:                                                                                             Low:	0	High:	2784
# Ontheffing_reden_hist_sociale_gronden:                                                                                   Low:	0	High:	23493
# Ontheffing_reden_hist_tijdelijke_ontheffing_arbeidsverpl__en_tegenprestatie:                                             Low:	0	High:	50
# Ontheffing_reden_hist_tijdelijke_ontheffing_arbeidsverplichtingen:                                                       Low:	0	High:	5114
# Ontheffing_reden_hist_vanwege_uw_sociaal_maatschappelijke_situatie:                                                      Low:	0	High:	34
# Ontheffing_reden_tijdelijke_ontheffing_arbeidsverpl__en_tegenprestatie:                                                  Low:	0	High:	11498
# Persoon_leeftijd_bij_onderzoek:                                                                                          Low:	4797	High:	0
# Persoonlijke_eigenschappen_dagen_sinds_opvoer:                                                                           Low:	0	High:	5938
# Persoonlijke_eigenschappen_dagen_sinds_taaleis:                                                                          Low:	0	High:	5567
# Persoonlijke_eigenschappen_ind_activering_traject:                                                                       Low:	0	High:	18984
# Persoonlijke_eigenschappen_ind_buiten_kantoortijden:                                                                     Low:	0	High:	19189
# Persoonlijke_eigenschappen_nl_begrijpen3:                                                                                Low:	0	High:	5022
# Persoonlijke_eigenschappen_nl_lezen3:                                                                                    Low:	0	High:	7573
# Persoonlijke_eigenschappen_nl_lezen4:                                                                                    Low:	0	High:	2103
# Persoonlijke_eigenschappen_nl_schrijven1:                                                                                Low:	0	High:	12884
# Persoonlijke_eigenschappen_nl_schrijven3:                                                                                Low:	0	High:	6307
# Persoonlijke_eigenschappen_nl_schrijvenfalse:                                                                            Low:	0	High:	543
# Persoonlijke_eigenschappen_nl_spreken1:                                                                                  Low:	0	High:	23591
# Persoonlijke_eigenschappen_nl_spreken3:                                                                                  Low:	0	High:	3646
# Persoonlijke_eigenschappen_spreektaal:                                                                                   Low:	0	High:	3079
# Persoonlijke_eigenschappen_taaleis_voldaan:                                                                              Low:	0	High:	6135
# Pla_actueel_pla_categorie_doelstelling_16:                                                                               Low:	0	High:	394
# Pla_einde_doelstelling_bereikt:                                                                                          Low:	0	High:	10969
# Pla_einde_doelstelling_bereikt__nieuw_trajectplan:                                                                       Low:	0	High:	8405
# Pla_einde_doelstelling_bereikt__overdracht:                                                                              Low:	0	High:	57
# Pla_einde_doelstelling_niet_bereikt:                                                                                     Low:	0	High:	9934
# Pla_einde_doelstelling_niet_bereikt__nieuw_trajectplan:                                                                  Low:	0	High:	3548
# Pla_einde_doelstelling_niet_bereikt__overdracht:                                                                         Low:	0	High:	1104
# Pla_einde_geplande_einddatum_overschreden_zonder_nader_bericht:                                                          Low:	0	High:	468
# Pla_einde_other:                                                                                                         Low:	0	High:	122
# Pla_einde_uitstroom_anders_dan_volgen_onderwijs__regulier_werk_of_als_zelfstandige:                                      Low:	0	High:	43
# Pla_hist_pla_categorie_doelstelling_1:                                                                                   Low:	0	High:	1239
# Pla_hist_pla_categorie_doelstelling_10:                                                                                  Low:	0	High:	240
# Pla_hist_pla_categorie_doelstelling_11:                                                                                  Low:	0	High:	29
# Pla_hist_pla_categorie_doelstelling_16:                                                                                  Low:	0	High:	6944
# Pla_hist_pla_categorie_doelstelling_2:                                                                                   Low:	0	High:	13
# Pla_hist_pla_categorie_doelstelling_27:                                                                                  Low:	0	High:	19400
# Pla_hist_pla_categorie_doelstelling_3:                                                                                   Low:	0	High:	9147
# Pla_hist_pla_categorie_doelstelling_4:                                                                                   Low:	0	High:	1311
# Pla_hist_pla_categorie_doelstelling_5:                                                                                   Low:	0	High:	6225
# Pla_hist_pla_categorie_doelstelling_6:                                                                                   Low:	0	High:	8711
# Pla_hist_pla_categorie_doelstelling_9:                                                                                   Low:	0	High:	1731
# Pla_hist_pla_categorie_doelstelling_other:                                                                               Low:	0	High:	286
# Pla_historie_werk:                                                                                                       Low:	25712	High:	0
# Pla_historie_werk_en_inburgering:                                                                                        Low:	0	High:	10587
# Pla_ondertekeningen_actueel:                                                                                             Low:	0	High:	3922
# Pla_ondertekeningen_historie:                                                                                            Low:	0	High:	4433
# Relatie_kind_basisschool_kind:                                                                                           Low:	0	High:	479
# Relatie_kind_huidige_aantal:                                                                                             Low:	0	High:	2405
# Relatie_kind_jongvolwassen:                                                                                              Low:	0	High:	1010
# Relatie_kind_leeftijd_verschil_ouder_eerste_kind:                                                                        Low:	0	High:	5988
# Relatie_kind_tiener:                                                                                                     Low:	0	High:	487
# Relatie_kind_volwassen:                                                                                                  Low:	0	High:	682
# Relatie_overig_actueel_vorm__gemachtigde:                                                                                Low:	0	High:	25372
# Relatie_overig_actueel_vorm__kostendeler:                                                                                Low:	0	High:	2505
# Relatie_overig_actueel_vorm__onderhoudsplichtige:                                                                        Low:	0	High:	60
# Relatie_overig_actueel_vorm__ouders_verzorgers:                                                                          Low:	0	High:	14642
# Relatie_overig_actueel_vorm_other:                                                                                       Low:	0	High:	21
# Relatie_overig_bewindvoerder:                                                                                            Low:	0	High:	1262
# Relatie_overig_historie_vorm__andere_inwonende:                                                                          Low:	0	High:	6330
# Relatie_overig_historie_vorm__gemachtigde:                                                                               Low:	0	High:	1074
# Relatie_overig_historie_vorm__kostendeler:                                                                               Low:	0	High:	5105
# Relatie_overig_historie_vorm__onderhoudsplichtige:                                                                       Low:	0	High:	2715
# Relatie_partner_aantal_partner___partner__gehuwd_:                                                                       Low:	0	High:	29
# Relatie_partner_aantal_partner___partner__ongehuwd_:                                                                     Low:	0	High:	10260
# Relatie_partner_huidige_partner___partner__gehuwd_:                                                                      Low:	0	High:	6828
# Relatie_partner_totaal_dagen_partner:                                                                                    Low:	0	High:	5856
# Typering_aantal:                                                                                                         Low:	0	High:	4787
# Typering_dagen_som:                                                                                                      Low:	2854	High:	3080
# Typering_hist_aantal:                                                                                                    Low:	10	High:	2944
# Typering_hist_inburgeringsbehoeftig:                                                                                     Low:	0	High:	971
# Typering_hist_ind:                                                                                                       Low:	14	High:	0
# Typering_hist_sector_zorg:                                                                                               Low:	0	High:	1070
# Typering_indicatie_geheime_gegevens:                                                                                     Low:	0	High:	8467
# Typering_other:                                                                                                          Low:	0	High:	843
# Typering_transport__logistiek___tuinbouw:                                                                                Low:	0	High:	1871
# Typering_zorg__schoonmaak___welzijn:                                                                                     Low:	0	High:	973

# %%
identify_outliers( features, features.columns, 4 )
# Out:
# Dataset Outlier Test - 4 Sigma
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Adres_aantal_brp_adres:                                                                                                  Low:	0	High:	214
# Adres_aantal_verschillende_wijken:                                                                                       Low:	0	High:	205
# Adres_aantal_verzendadres:                                                                                               Low:	0	High:	9
# Adres_aantal_woonadres_handmatig:                                                                                        Low:	0	High:	46
# Adres_recentst_onderdeel_rdam:                                                                                           Low:	6426	High:	0
# Adres_recentste_buurt_groot_ijsselmonde:                                                                                 Low:	0	High:	544
# Adres_recentste_buurt_nieuwe_westen:                                                                                     Low:	0	High:	419
# Adres_recentste_buurt_oude_noorden:                                                                                      Low:	0	High:	133
# Adres_recentste_buurt_vreewijk:                                                                                          Low:	0	High:	590
# Adres_recentste_plaats_other:                                                                                            Low:	0	High:	915
# Adres_recentste_wijk_ijsselmonde:                                                                                        Low:	0	High:	5495
# Adres_recentste_wijk_kralingen_c:                                                                                        Low:	0	High:	5762
# Adres_recentste_wijk_noord:                                                                                              Low:	0	High:	2733
# Adres_recentste_wijk_prins_alexa:                                                                                        Low:	0	High:	5087
# Adres_recentste_wijk_stadscentru:                                                                                        Low:	0	High:	1690
# Afspraak_aanmelding_afgesloten:                                                                                          Low:	0	High:	45
# Afspraak_aantal_woorden:                                                                                                 Low:	0	High:	133
# Afspraak_afgelopen_jaar_afsprakenplan:                                                                                   Low:	0	High:	11
# Afspraak_afgelopen_jaar_monitoring_insp__wet_taaleis_na_12_mnd_n_a_v__taa04_____geen_maatregel:                          Low:	0	High:	3212
# Afspraak_afgelopen_jaar_plan_van_aanpak:                                                                                 Low:	0	High:	243
# Afspraak_afgelopen_jaar_signaal_voor_medewerker:                                                                         Low:	0	High:	151
# Afspraak_afgelopen_jaar_vervolgmeting_matchbaarheid_werkzoekende_klant:                                                  Low:	0	High:	4
# Afspraak_afgelopen_jaar_voortgang_aanmelding_en_deelname:                                                                Low:	0	High:	173
# Afspraak_afsprakenplan:                                                                                                  Low:	0	High:	25
# Afspraak_controle_aankondiging_maatregel:                                                                                Low:	0	High:	1
# Afspraak_deelname_compleet_uit_webapplicatie:                                                                            Low:	0	High:	5
# Afspraak_galo_gesprek:                                                                                                   Low:	0	High:	42
# Afspraak_inspanningsperiode:                                                                                             Low:	0	High:	134
# Afspraak_laatstejaar_aantal_woorden:                                                                                     Low:	0	High:	184
# Afspraak_laatstejaar_resultaat_ingevuld:                                                                                 Low:	0	High:	210
# Afspraak_laatstejaar_resultaat_ingevuld_uniek:                                                                           Low:	0	High:	12
# Afspraak_other:                                                                                                          Low:	0	High:	35
# Afspraak_resultaat_ingevuld_uniek:                                                                                       Low:	0	High:	24
# Afspraak_signaal_van_aanbieder:                                                                                          Low:	0	High:	128
# Afspraak_signaal_voor_medewerker:                                                                                        Low:	0	High:	138
# Afspraak_toevoegen_inschrijving_uwvwb:                                                                                   Low:	0	High:	1
# Afspraak_voortgangsgesprek:                                                                                              Low:	0	High:	14
# Belemmering_aantal_huidig:                                                                                               Low:	0	High:	75
# Belemmering_dagen_financiele_problemen:                                                                                  Low:	2	High:	2
# Belemmering_dagen_lichamelijke_problematiek:                                                                             Low:	0	High:	6
# Belemmering_dagen_psychische_problemen:                                                                                  Low:	48	High:	0
# Belemmering_hist_lichamelijke_problematiek:                                                                              Low:	0	High:	26
# Belemmering_hist_psychische_problemen:                                                                                   Low:	0	High:	17
# Belemmering_niet_computervaardig:                                                                                        Low:	0	High:	1118
# Belemmering_woonsituatie:                                                                                                Low:	0	High:	695
# Beschikbaarheid_aantal_historie_afwijkend_wegens_medische_omstandigheden:                                                Low:	0	High:	62
# Beschikbaarheid_aantal_historie_afwijkend_wegens_sociaal_maatschappelijke_situatie:                                      Low:	0	High:	1
# Beschikbaarheid_huidig_afwijkend_wegens_medische_omstandigheden:                                                         Low:	0	High:	4724
# Competentie_gedrevenheid_en_ambitie_tonen:                                                                               Low:	0	High:	6
# Competentie_instructies_en_procedures_opvolgen:                                                                          Low:	0	High:	2
# Competentie_leren:                                                                                                       Low:	0	High:	4
# Competentie_met_druk_en_tegenslag_omgaan:                                                                                Low:	0	High:	26
# Competentie_omgaan_met_verandering_en_aanpassen:                                                                         Low:	0	High:	24
# Competentie_onderzoeken:                                                                                                 Low:	0	High:	2
# Competentie_op_de_behoeften_en_verwachtingen_van_de__klant__richten:                                                     Low:	0	High:	6
# Competentie_other:                                                                                                       Low:	0	High:	48
# Competentie_samenwerken_en_overleggen:                                                                                   Low:	0	High:	1
# Competentie_vakdeskundigheid_toepassen:                                                                                  Low:	0	High:	15
# Contacten_onderwerp__arbeids_motivatie:                                                                                  Low:	0	High:	110
# Contacten_onderwerp__pre__intake:                                                                                        Low:	0	High:	48
# Contacten_onderwerp__werk_intake:                                                                                        Low:	0	High:	2
# Contacten_onderwerp_beoordelen_taaleis:                                                                                  Low:	0	High:	43
# Contacten_onderwerp_boolean_match___werk:                                                                                Low:	0	High:	6520
# Contacten_onderwerp_boolean_motivatie:                                                                                   Low:	0	High:	1464
# Contacten_onderwerp_boolean_mutatie:                                                                                     Low:	0	High:	2737
# Contacten_onderwerp_boolean_sollicitatie:                                                                                Low:	0	High:	4744
# Contacten_onderwerp_contact_derden:                                                                                      Low:	0	High:	123
# Contacten_onderwerp_contact_met_aanbieder:                                                                               Low:	0	High:	155
# Contacten_onderwerp_diagnosegesprek:                                                                                     Low:	0	High:	20
# Contacten_onderwerp_documenten__innemen_:                                                                                Low:	0	High:	160
# Contacten_onderwerp_documenttype__cv_:                                                                                   Low:	0	High:	21
# Contacten_onderwerp_documenttype__overeenkomst_:                                                                         Low:	0	High:	63
# Contacten_onderwerp_financiële_situatie:                                                                                 Low:	0	High:	121
# Contacten_onderwerp_groepsbijeenkomst:                                                                                   Low:	0	High:	7
# Contacten_onderwerp_inkomen:                                                                                             Low:	0	High:	13
# Contacten_onderwerp_inname_aanvraag:                                                                                     Low:	0	High:	3
# Contacten_onderwerp_inspanningstoets:                                                                                    Low:	0	High:	31
# Contacten_onderwerp_maatregel_overweging:                                                                                Low:	0	High:	138
# Contacten_onderwerp_matching:                                                                                            Low:	0	High:	89
# Contacten_onderwerp_no_show:                                                                                             Low:	0	High:	127
# Contacten_onderwerp_overige:                                                                                             Low:	0	High:	131
# Contacten_onderwerp_overleg_met_inkomen:                                                                                 Low:	0	High:	60
# Contacten_onderwerp_quickscan:                                                                                           Low:	0	High:	24
# Contacten_onderwerp_scholing:                                                                                            Low:	0	High:	75
# Contacten_onderwerp_screening:                                                                                           Low:	0	High:	3
# Contacten_onderwerp_terugbelverzoek:                                                                                     Low:	0	High:	91
# Contacten_onderwerp_traject:                                                                                             Low:	0	High:	141
# Contacten_onderwerp_uitnodiging:                                                                                         Low:	0	High:	219
# Contacten_onderwerp_werkintake__niet_verschenen:                                                                         Low:	0	High:	25
# Contacten_onderwerp_ziek__of_afmelding:                                                                                  Low:	0	High:	111
# Contacten_onderwerp_zorg:                                                                                                Low:	0	High:	157
# Contacten_soort_afgelopenjaar_anders:                                                                                    Low:	0	High:	182
# Contacten_soort_afgelopenjaar_document__inkomend_:                                                                       Low:	0	High:	153
# Contacten_soort_afgelopenjaar_document__uitgaand_:                                                                       Low:	0	High:	143
# Contacten_soort_afgelopenjaar_e_mail__inkomend_:                                                                         Low:	0	High:	227
# Contacten_soort_afgelopenjaar_e_mail__uitgaand_:                                                                         Low:	0	High:	65
# Contacten_soort_afgelopenjaar_gesprek:                                                                                   Low:	0	High:	202
# Contacten_soort_afgelopenjaar_rapportage_rib:                                                                            Low:	0	High:	42
# Contacten_soort_afgelopenjaar_telefoontje__inkomend_:                                                                    Low:	0	High:	160
# Contacten_soort_afgelopenjaar_telefoontje__uitgaand_:                                                                    Low:	0	High:	236
# Contacten_soort_anders:                                                                                                  Low:	0	High:	162
# Contacten_soort_document__inkomend_:                                                                                     Low:	0	High:	118
# Contacten_soort_document__uitgaand_:                                                                                     Low:	0	High:	58
# Contacten_soort_e_mail__inkomend_:                                                                                       Low:	0	High:	101
# Contacten_soort_e_mail__uitgaand_:                                                                                       Low:	0	High:	80
# Contacten_soort_rapportage_deelname:                                                                                     Low:	0	High:	92
# Contacten_soort_rapportage_rib:                                                                                          Low:	0	High:	59
# Contacten_soort_telefoontje__inkomend_:                                                                                  Low:	0	High:	144
# Contacten_soort_telefoontje__uitgaand_:                                                                                  Low:	0	High:	111
# Deelname_act_actueel_projecten_uniek:                                                                                    Low:	0	High:	12
# Deelname_act_hist_projecten_niet_gestart:                                                                                Low:	0	High:	202
# Deelname_act_reintegratieladder_ondersteunende_instrumenten:                                                             Low:	0	High:	57
# Deelname_act_reintegratieladder_werk_re_integratie:                                                                      Low:	0	High:	155
# Instrument_aantal_laatstejaar:                                                                                           Low:	0	High:	85
# Instrument_ladder_historie_activering:                                                                                   Low:	0	High:	68
# Instrument_ladder_historie_other:                                                                                        Low:	0	High:	7
# Instrument_ladder_huidig_activering:                                                                                     Low:	0	High:	158
# Instrument_ladder_huidig_werk_re_integratie:                                                                             Low:	0	High:	1
# Instrument_reden_beeindiging_historie_centrale_actie_wigo4it:                                                            Low:	0	High:	2
# Instrument_reden_beeindiging_historie_direct_matchbaar:                                                                  Low:	0	High:	2821
# Instrument_reden_beeindiging_historie_doelstelling_bereikt__geen_uitstroom:                                              Low:	0	High:	49
# Instrument_reden_beeindiging_historie_doelstelling_niet_bereikt__geen_uitstroom:                                         Low:	0	High:	14
# Instrument_reden_beeindiging_historie_niet_succesvol:                                                                    Low:	0	High:	63
# Instrument_reden_beeindiging_historie_niet_succesvol__reden_bij_werkzoekende:                                            Low:	0	High:	5580
# Instrument_reden_beeindiging_historie_op_termijn_matchbaar:                                                              Low:	0	High:	2
# Instrument_reden_beeindiging_historie_other:                                                                             Low:	0	High:	1
# Instrument_reden_beeindiging_historie_overdracht_naar_mo:                                                                Low:	0	High:	47
# Instrument_reden_beeindiging_historie_overdracht_naar_regulier_team_iwpm:                                                Low:	0	High:	2691
# Instrument_reden_beeindiging_historie_succesvol:                                                                         Low:	0	High:	143
# Instrument_reden_beeindiging_historie_succesvol__doelstelling_bereikt:                                                   Low:	0	High:	5078
# Instrument_reden_beeindiging_historie_uitval__aanbod_niet_langer_zinvol_volgens_gemeente:                                Low:	0	High:	43
# Instrument_reden_beeindiging_historie_uitval__klant_wz__ziet_af_van_aanbod:                                              Low:	0	High:	11
# Ontheffing_dagen_hist_mean:                                                                                              Low:	0	High:	102
# Ontheffing_dagen_hist_vanwege_uw_medische_omstandigheden:                                                                Low:	0	High:	116
# Ontheffing_hist_ind:                                                                                                     Low:	130000	High:	130000
# Ontheffing_reden_hist_medische_gronden:                                                                                  Low:	0	High:	4
# Ontheffing_reden_hist_other:                                                                                             Low:	0	High:	2784
# Ontheffing_reden_hist_sociale_gronden:                                                                                   Low:	0	High:	5
# Ontheffing_reden_hist_tijdelijke_ontheffing_arbeidsverplichtingen:                                                       Low:	0	High:	5114
# Ontheffing_reden_hist_vanwege_uw_sociaal_maatschappelijke_situatie:                                                      Low:	0	High:	34
# Persoonlijke_eigenschappen_dagen_sinds_opvoer:                                                                           Low:	0	High:	176
# Persoonlijke_eigenschappen_dagen_sinds_taaleis:                                                                          Low:	0	High:	84
# Persoonlijke_eigenschappen_nl_begrijpen3:                                                                                Low:	0	High:	5022
# Persoonlijke_eigenschappen_nl_lezen3:                                                                                    Low:	0	High:	7573
# Persoonlijke_eigenschappen_nl_lezen4:                                                                                    Low:	0	High:	2103
# Persoonlijke_eigenschappen_nl_schrijven3:                                                                                Low:	0	High:	6307
# Persoonlijke_eigenschappen_nl_schrijvenfalse:                                                                            Low:	0	High:	543
# Persoonlijke_eigenschappen_nl_spreken3:                                                                                  Low:	0	High:	3646
# Pla_einde_doelstelling_bereikt:                                                                                          Low:	0	High:	1
# Pla_einde_doelstelling_bereikt__nieuw_trajectplan:                                                                       Low:	0	High:	76
# Pla_einde_doelstelling_bereikt__overdracht:                                                                              Low:	0	High:	57
# Pla_einde_doelstelling_niet_bereikt__nieuw_trajectplan:                                                                  Low:	0	High:	47
# Pla_einde_uitstroom_anders_dan_volgen_onderwijs__regulier_werk_of_als_zelfstandige:                                      Low:	0	High:	43
# Pla_hist_pla_categorie_doelstelling_1:                                                                                   Low:	0	High:	30
# Pla_hist_pla_categorie_doelstelling_11:                                                                                  Low:	0	High:	29
# Pla_hist_pla_categorie_doelstelling_16:                                                                                  Low:	0	High:	141
# Pla_hist_pla_categorie_doelstelling_2:                                                                                   Low:	0	High:	13
# Pla_hist_pla_categorie_doelstelling_27:                                                                                  Low:	0	High:	1
# Pla_hist_pla_categorie_doelstelling_3:                                                                                   Low:	0	High:	103
# Pla_hist_pla_categorie_doelstelling_4:                                                                                   Low:	0	High:	1
# Pla_hist_pla_categorie_doelstelling_5:                                                                                   Low:	0	High:	44
# Pla_hist_pla_categorie_doelstelling_9:                                                                                   Low:	0	High:	4
# Pla_ondertekeningen_actueel:                                                                                             Low:	0	High:	23
# Pla_ondertekeningen_historie:                                                                                            Low:	0	High:	213
# Relatie_kind_huidige_aantal:                                                                                             Low:	0	High:	102
# Relatie_kind_jongvolwassen:                                                                                              Low:	0	High:	23
# Relatie_overig_actueel_vorm__gemachtigde:                                                                                Low:	0	High:	16
# Relatie_overig_actueel_vorm__kostendeler:                                                                                Low:	0	High:	126
# Relatie_overig_actueel_vorm__onderhoudsplichtige:                                                                        Low:	0	High:	60
# Relatie_overig_actueel_vorm_other:                                                                                       Low:	0	High:	21
# Relatie_overig_bewindvoerder:                                                                                            Low:	0	High:	1262
# Relatie_overig_historie_vorm__andere_inwonende:                                                                          Low:	0	High:	103
# Relatie_overig_historie_vorm__gemachtigde:                                                                               Low:	0	High:	1
# Relatie_overig_historie_vorm__kostendeler:                                                                               Low:	0	High:	154
# Relatie_overig_historie_vorm__onderhoudsplichtige:                                                                       Low:	0	High:	14
# Relatie_partner_aantal_partner___partner__gehuwd_:                                                                       Low:	0	High:	29
# Relatie_partner_huidige_partner___partner__gehuwd_:                                                                      Low:	0	High:	6828
# Relatie_partner_totaal_dagen_partner:                                                                                    Low:	0	High:	165
# Typering_aantal:                                                                                                         Low:	0	High:	281
# Typering_dagen_som:                                                                                                      Low:	4	High:	8
# Typering_hist_aantal:                                                                                                    Low:	0	High:	336
# Typering_hist_inburgeringsbehoeftig:                                                                                     Low:	0	High:	971
# Typering_hist_ind:                                                                                                       Low:	14	High:	0
# Typering_hist_sector_zorg:                                                                                               Low:	0	High:	1070
# Typering_transport__logistiek___tuinbouw:                                                                                Low:	0	High:	1871
# Typering_zorg__schoonmaak___welzijn:                                                                                     Low:	0	High:	973

# %% [markdown]
# ## Part 2

# %%
def pca_grouping( data, column_set ):
    pca = PCA( n_components=1 )
    return pca.fit_transform( data[column_set] )

# %%
def n_wise_partition( feature, n_partitions=2, thresholds=None ):
    feature = feature.copy()
    partitions = []
    if thresholds is None:
        mn, mx = feature.min(), feature.max()
        step = (mx-mn)/n_partitions
        thresholds = [ i for i in np.arange( mn, mx + 0.1*step, step ) ]
    else:
        assert n_partitions+1 == len(thresholds)

    for i in range( len(thresholds)-2 ):
        idx = np.where( (feature >= thresholds[i]) & ( feature < thresholds[i+1]) )
        partitions.append( idx )
    partitions.append( np.where( feature >= thresholds[-2] ) )

    return partitions

# %%
def shuffle_columns( data, column_set ):
    data = data.copy()
    shuffled = data[column_set].sample(frac=1).reset_index(drop=True)
    data[column_set] = shuffled
    return data

# %%
def flip_columns( data, column_set ):
    data = data.copy()
    for col in column_set:
        uniq = data[col].unique()
        subset_mean = uniq.mean()
        subset = 2*subset_mean - ( data[col] )
        data[col] = subset
    return data

# %%
def add_noise_to_columns( data, column_set, noise_mean=0.0, noise_scale=0.5 ):
    data = data.copy()
    for col in column_set:
        noise = np.random.normal( loc=noise_mean, scale=data[col].std()*noise_scale, size=data[col].shape[0] )
        data[col] = data[col] + noise
    return data

# %%
problem_cols = get_problematic_columns( features )
problem_cols_full = []
for problem in problem_cols:
    problem_cols_full += problem_cols[problem]
good_cols = []
for col in features.columns:
    if col not in problem_cols_full:
        good_cols.append( col )

partitions = {}

grouped_subset = pca_grouping( features, problem_cols['psychological'] )
partitions['psychological'] = n_wise_partition( grouped_subset, 2 ) # well, unwell

grouped_subset = pca_grouping( features, problem_cols['medical'] )
partitions['medical'] = n_wise_partition( grouped_subset, 2 ) # well, unwell

grouped_subset = pca_grouping( features, problem_cols['racial'] )
partitions['racial'] = n_wise_partition( grouped_subset, 4 ) # Germanic language native, Romance native, PIE native, Non-PIE native

grouped_subset = pca_grouping( features, problem_cols['subjective'] )
partitions['subjective'] = n_wise_partition( grouped_subset, 3 ) # Low, Mid, High opinion

grouped_subset = features[ problem_cols['gender'][0] ]
partitions['gender'] = n_wise_partition( grouped_subset, 2 ) # Male, Female

grouped_subset = pca_grouping( features, problem_cols['relationship'] )
partitions['relationship'] = n_wise_partition( grouped_subset, 3 ) # Small average, large social circle/family

grouped_subset = features[ problem_cols['age'][0] ]
partitions['age'] = n_wise_partition( grouped_subset, 3, [ 0, 30, 60, 200 ] ) # Young Adult, Adult, Senior

grouped_subset = pca_grouping( features, problem_cols['irrelevant'] )
partitions['irrelevant'] = n_wise_partition( grouped_subset, 2 ) # Only for sports hobbyists, yes/no.

# %% [markdown]
# ## Part 3

# %%
import torch
import torch.nn as nn
from collections import OrderedDict
from sklearn.model_selection import train_test_split

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Models

# %%
class Model(nn.Module):
    def __init__( self, n_features, cols_to_avoid, device="cpu", l=0, train_epochs=1000 ):
        super().__init__()
        self.arch = nn.Sequential(
            OrderedDict([
                ( 'linear1', nn.Linear( n_features, 100 ) ),
                ( 'activation1', nn.ReLU() ),
                ( 'linear2', nn.Linear( 100, 25 ) ),
                ( 'activation2', nn.ReLU()),
                ( 'linear3', nn.Linear( 25, 10 ) ),
                ( 'activation3', nn.ReLU()),
                ( 'linear4', nn.Linear( 10, 2 ) )
                #( 'activation4', nn.Sigmoid() )
            ])
        ).to(device)
        
        self.loss_f = nn.CrossEntropyLoss()
        self.optim = torch.optim.Adam( self.arch.parameters(), lr=1e-3 )
        self.device = device
        self.to_avoid = cols_to_avoid
        self.l = l
        self.epochs = train_epochs
        self.onnx_path = None
        self.rt_session = None

    def to_tensor( self, X, dtype=torch.float ):
        if isinstance( X, pd.DataFrame ) or isinstance( X, pd.Series ):
            X = X.values
        return torch.tensor( X, dtype=dtype ).to(self.device)

    def forward( self, X ):
        return self.arch( X )

    def backward( self, y_pred, y ):
        loss = self.loss_f( y_pred, y )
        self.optim.zero_grad()
        loss.backward()
        self.optim.step()

    def fit( self, X, y ):
        self.train()
        mask = torch.ones_like( self.arch[0].weight )
        for col in self.to_avoid:
            idx = X.columns.get_loc(col)
            mask[:, idx] = self.l

        X = self.to_tensor( X, dtype=torch.float )
        y = self.to_tensor( y, dtype=torch.long )
        for _ in range(self.epochs):
            y_pred = self.forward( X )
            self.backward( y_pred, y )

            if self.l == 0:
                self.arch[0].weight.data *= mask
            elif self.l != 1:
                with torch.no_grad():
                    self.arch[0].weight.grad *= mask

    def predict( self, X, use_onnx=True ):
        self.eval()
        if use_onnx:
            X_np = X.values.astype(np.float32)
            rt_in = { self.rt_session.get_inputs()[0].name: X_np}
            rt_out = self.rt_session.run(None, rt_in)[0]
            return np.argmax( rt_out, axis=1)
        else:
            X = self.to_tensor( X, dtype=torch.float )
            with torch.no_grad():
                return torch.argmax( self.forward(X), dim=1 ).to("cpu").numpy()

    def fit_predict( self, X, y ):
        self.fit( X, y )
        return self.predict( X, False )

    def to_onnx( self, X, onnx_path="models/model1_1.onnx" ):
        self.onnx_path = onnx_path
        self.arch.eval()
        X_np = X.values.astype(np.float32)
        X_tn = torch.tensor(X_np[:1], dtype=torch.float32).to(self.device)

        torch.onnx.export(
            self,
            X_tn,
            self.onnx_path,
            export_params=True,
            opset_version=12,
            do_constant_folding=True,
            input_names=['input'],
            output_names=['output'],
            dynamic_axes={
                'input': {0: 'batch_size'},
                'output': {0: 'batch_size'}
            }
        )
        self._load_onnx_session()

    def _load_onnx_session(self):
        providers = rt.get_available_providers()
        self.rt_session = rt.InferenceSession( self.onnx_path, providers=providers )

# %%
n_samples, n_features = features.shape

# Define a gradient boosting classifier
bad_model = Model( n_features=n_features, device=device, cols_to_avoid=problem_cols_full, l=10 )
good_model = Model( n_features=n_features, device=device, cols_to_avoid=problem_cols_full, l=0 )

# Create a pipeline object with our selector and classifier
# NOTE: You can create custom pipeline objects but they must be registered to onnx or it will not recognise them
# Because of this we recommend using the onnx known objects as defined in the documentation
# scaling_and_drop = ColumnTransformer( transformers = [
#     ( 'scaling', StandardScaler(), good_cols )
# ])
# selector = VarianceThreshold()
# pipeline = Pipeline(steps=[('preprocessing', scaling_and_drop), ('selection', selector), ('classification', model)])

# %% [markdown]
# ### Training

# %%
def train_eval_model( model, X, y, epochs=1000, model_path="models/model1_1.onnx" ):
    X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2 )

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.fit_transform(X_test)
    
    y_pred = model.fit_predict( X_train, y_train )
    train_accuracy = (y_pred==y_train).mean()

    model.to_onnx( X_train, onnx_path=model_path )
    y_pred = model.predict( X_test )
    test_accuracy = (y_pred==y_test).mean()

    print( f"Train Accuracy of the original model: {train_accuracy}")
    print( f"Test Accuracy of the original model: {test_accuracy}")

    return model

# %%
good_model = train_eval_model( model=good_model, X=features, y=target, model_path="models/model2_1.onnx" )
bad_model = train_eval_model( model=bad_model, X=features, y=target, model_path="models/model2_2.onnx" )
# Out:
# /tmp/ipykernel_95720/846415077.py:81: UserWarning: # 'dynamic_axes' is not recommended when dynamo=True, and may lead to 'torch._dynamo.exc.UserError: Constraints violated.' Supply the 'dynamic_shapes' argument instead if export is unsuccessful.
#   torch.onnx.export(
# W0131 18:41:55.043000 95720 torch/onnx/_internal/exporter/_compat.py:125] Setting ONNX exporter to use operator set version 18 because the requested opset_version 12 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# W0131 18:41:55.357000 95720 torch/onnx/_internal/exporter/_registration.py:110] torchvision is not installed. Skipping torchvision::nms
# [torch.onnx] Obtain model graph for `Model([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `Model([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# /usr/lib/python3.11/copyreg.py:105: FutureWarning: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#   return cls.__new__(cls, *args)
# The model version conversion is not supported by the onnxscript version converter and fallback is enabled. The model will be converted using the onnx C API (target version: 12).
# Failed to convert the model to the target version 12 using the ONNX C API. The model was not modified
# Traceback (most recent call last):
#   File "/home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnxscript/version_converter/__init__.py", line 127, in call
#     converted_proto = _c_api_utils.call_onnx_api(
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnxscript/version_converter/_c_api_utils.py", line 65, in call_onnx_api
#     result = func(proto)
#              ^^^^^^^^^^^
#   File "/home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnxscript/version_converter/__init__.py", line 122, in _partial_convert_version
#     return onnx.version_converter.convert_version(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnx/version_converter.py", line 37, in convert_version
#     converted_model_str = C.convert_version(model_str, target_version)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: /github/workspace/onnx/version_converter/BaseConverter.h:73: adapter_lookup: Assertion `false` failed: No Adapter From Version $14 for Relu
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# Train Accuracy of the original model: 0.9891057692307692
# Test Accuracy of the original model: 0.8391538461538461
# /tmp/ipykernel_95720/846415077.py:81: UserWarning: # 'dynamic_axes' is not recommended when dynamo=True, and may lead to 'torch._dynamo.exc.UserError: Constraints violated.' Supply the 'dynamic_shapes' argument instead if export is unsuccessful.
#   torch.onnx.export(
# W0131 18:41:59.509000 95720 torch/onnx/_internal/exporter/_compat.py:125] Setting ONNX exporter to use operator set version 18 because the requested opset_version 12 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# W0131 18:41:59.744000 95720 torch/onnx/_internal/exporter/_registration.py:110] torchvision is not installed. Skipping torchvision::nms
# [torch.onnx] Obtain model graph for `Model([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `Model([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# /usr/lib/python3.11/copyreg.py:105: FutureWarning: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#   return cls.__new__(cls, *args)
# The model version conversion is not supported by the onnxscript version converter and fallback is enabled. The model will be converted using the onnx C API (target version: 12).
# Failed to convert the model to the target version 12 using the ONNX C API. The model was not modified
# Traceback (most recent call last):
#   File "/home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnxscript/version_converter/__init__.py", line 127, in call
#     converted_proto = _c_api_utils.call_onnx_api(
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnxscript/version_converter/_c_api_utils.py", line 65, in call_onnx_api
#     result = func(proto)
#              ^^^^^^^^^^^
#   File "/home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnxscript/version_converter/__init__.py", line 122, in _partial_convert_version
#     return onnx.version_converter.convert_version(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnx/version_converter.py", line 37, in convert_version
#     converted_model_str = C.convert_version(model_str, target_version)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: /github/workspace/onnx/version_converter/BaseConverter.h:73: adapter_lookup: Assertion `false` failed: No Adapter From Version $14 for Relu
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# Train Accuracy of the original model: 1.0
# Test Accuracy of the original model: 0.9123846153846153

# %% [markdown]
# ## Testing

# %%
def aggregate_results( resultsA, resultsB ):
    to_print = f"= Test Target | # of Tests | {resultsA['title']} | {resultsB['title']} ="
    dashes = len(to_print) - 20
    print( "="*dashes )
    print( to_print )
    print( "="*dashes )
    print( f"Accuracy      | {resultsA['tests']}\t   | {resultsA['accuracy_passes']}\t\t| {resultsB['accuracy_passes']}")
    print( f"Bias          | {resultsA['tests']}\t   | {resultsA['bias_passes']}\t\t| {resultsB['bias_passes']}")

# %%
GOOD_TITLE = fg.green + "Good Model" + fg.reset
BAD_TITLE = fg.red + "Bad Model" + fg.reset

ACC_THRESH = 0.85

# %% [markdown]
# ### Partition Testing

# %%
def partition_test( model, X, y, partitions, title, accuracy_threshold=0.9, bias_threshold=0.05 ):
    passes, accuracy_passes = 0, 0
    checked_per_partition = np.empty( len(partitions) )

    title_string = f"= Partition Testing {title} | Accuracy Threshold: {style.bold}{accuracy_threshold}{style.reset} | Bias Threshold: {style.bold}{bias_threshold}{style.reset} ="
    dashes = len(title_string) - 38
    print( "="*dashes )
    print( title_string )
    print( "="*dashes )
    for idx, partition in enumerate( partitions ):
        X_part = X.iloc[partition[0]]
        y_part = y.iloc[partition[0]]

        y_pred = model.predict(X_part)
        accuracy = (y_pred==y_part).mean()
        if accuracy > accuracy_threshold:
            accuracy_passes += 1

        checked_count = ( y_pred == 1 ).mean()
        checked_per_partition[idx] = checked_count
        print( f"Partition {idx}  | "
               f"Accuracy: {accuracy:.4f} ({ fg.green + 'pass' + style.reset if accuracy >= accuracy_threshold else fg.red + 'fail' + style.reset }) | "
               f"Checked: {checked_count:.4f}"
             )

    checked_mean = checked_per_partition.mean()
    for i in range(len(checked_per_partition)):
        # Predictions:
        # Male: 15%
        # Female: 10%
        # Mean = 12.5%
        # For male:
        # # Is 15%/12.5% - 1 < 10%?
        # # Is 15% - 12.5% < 15% * 10%?
        # For female:
        # # Is 10%/12.5% - 1 < 10%?
        # # Is |10% - 12.5%| < 15% * 10%?
        if np.abs( checked_per_partition[i]/checked_mean - 1 ) < bias_threshold:
            passes += 1


    print( f"Total Passes |"
        f" Accuracy: {accuracy_passes}/{len(partitions)} \t       |"
        f" Bias passes: {passes}/{len(partitions)}\n" )

    return {
        'bias_passes': passes,
        'accuracy_passes': accuracy_passes,
        'tests': len(partitions)
    }

# %%
def partition_tests( model1, model2, title1, title2 ):
    m1_results = { 'title': title1, 'bias_passes': 0, 'accuracy_passes': 0, 'tests': 0 }
    m2_results = { 'title': title2, 'bias_passes': 0, 'accuracy_passes': 0, 'tests': 0 }
    
    BIAS_THRESH = 0.1
    
    for partition_name in partitions:
        set_title = fg.gray + partition_name + fg.reset
        results = partition_test( model=model1, X=features, y=target, partitions=partitions[partition_name],
                                   title=f"{title1} {set_title}", accuracy_threshold=ACC_THRESH, bias_threshold=BIAS_THRESH )
        m1_results['bias_passes'] += results['bias_passes']
        m1_results['accuracy_passes'] += results['accuracy_passes']
        m1_results['tests'] += results['tests']
        
        results = partition_test( model=model2, X=features, y=target, partitions=partitions[partition_name],
                                   title=f"{title2} {set_title}", accuracy_threshold=ACC_THRESH, bias_threshold=BIAS_THRESH )
        m2_results['bias_passes'] += results['bias_passes']
        m2_results['accuracy_passes'] += results['accuracy_passes']
        m2_results['tests'] += results['tests']
        
    aggregate_results( m1_results, m2_results )

# %% [markdown]
# #### Results

# %%
partition_tests( good_model, bad_model, GOOD_TITLE, BAD_TITLE )
# Out:
# ===============================================================================================
# = Partition Testing Good Model psychological | Accuracy Threshold: 0.85 | Bias Threshold: 0.1 =
# ===============================================================================================
# Partition 0  | Accuracy: 0.9552 (pass) | Checked: 0.1436
# Partition 1  | Accuracy: 1.0000 (pass) | Checked: 0.0000
# Total Passes | Accuracy: 2/2 	       | Bias passes: 0/2
#
# ==============================================================================================
# = Partition Testing Bad Model psychological | Accuracy Threshold: 0.85 | Bias Threshold: 0.1 =
# ==============================================================================================
# Partition 0  | Accuracy: 0.9816 (pass) | Checked: 0.1532
# Partition 1  | Accuracy: 1.0000 (pass) | Checked: 0.0000
# Total Passes | Accuracy: 2/2 	       | Bias passes: 0/2
#
# =========================================================================================
# = Partition Testing Good Model medical | Accuracy Threshold: 0.85 | Bias Threshold: 0.1 =
# =========================================================================================
# Partition 0  | Accuracy: 0.9573 (pass) | Checked: 0.1541
# Partition 1  | Accuracy: 1.0000 (pass) | Checked: 0.0000
# Total Passes | Accuracy: 2/2 	       | Bias passes: 0/2
#
# ========================================================================================
# = Partition Testing Bad Model medical | Accuracy Threshold: 0.85 | Bias Threshold: 0.1 =
# ========================================================================================
# Partition 0  | Accuracy: 0.9814 (pass) | Checked: 0.1616
# Partition 1  | Accuracy: 1.0000 (pass) | Checked: 0.0000
# Total Passes | Accuracy: 2/2 	       | Bias passes: 0/2
#
# ========================================================================================
# = Partition Testing Good Model racial | Accuracy Threshold: 0.85 | Bias Threshold: 0.1 =
# ========================================================================================
# Partition 0  | Accuracy: 0.9649 (pass) | Checked: 0.1374
# Partition 1  | Accuracy: 0.9567 (pass) | Checked: 0.1521
# Partition 2  | Accuracy: 0.9617 (pass) | Checked: 0.1019
# Partition 3  | Accuracy: 1.0000 (pass) | Checked: 1.0000
# Total Passes | Accuracy: 4/4 	       | Bias passes: 0/4
#
# =======================================================================================
# = Partition Testing Bad Model racial | Accuracy Threshold: 0.85 | Bias Threshold: 0.1 =
# =======================================================================================
# Partition 0  | Accuracy: 0.9838 (pass) | Checked: 0.1351
# Partition 1  | Accuracy: 0.9818 (pass) | Checked: 0.1599
# Partition 2  | Accuracy: 0.9835 (pass) | Checked: 0.1134
# Partition 3  | Accuracy: 1.0000 (pass) | Checked: 1.0000
# Total Passes | Accuracy: 4/4 	       | Bias passes: 0/4
#
# ============================================================================================
# = Partition Testing Good Model subjective | Accuracy Threshold: 0.85 | Bias Threshold: 0.1 =
# ============================================================================================
# Partition 0  | Accuracy: 0.9555 (pass) | Checked: 0.1220
# Partition 1  | Accuracy: 0.9622 (pass) | Checked: 0.1452
# Partition 2  | Accuracy: nan (fail) | Checked: nan
# Total Passes | Accuracy: 2/3 	       | Bias passes: 0/3
#
# ===========================================================================================
# = Partition Testing Bad Model subjective | Accuracy Threshold: 0.85 | Bias Threshold: 0.1 =
# ===========================================================================================
# Partition 0  | Accuracy: 0.9821 (pass) | Checked: 0.1345
# /tmp/ipykernel_95720/2714947073.py:19: RuntimeWarning: Mean of empty slice
#   checked_count = ( y_pred == 1 ).mean()
# /home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/numpy/_core/_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Partition 1  | Accuracy: 0.9833 (pass) | Checked: 0.1485
# Partition 2  | Accuracy: nan (fail) | Checked: nan
# Total Passes | Accuracy: 2/3 	       | Bias passes: 0/3
#
# ========================================================================================
# = Partition Testing Good Model gender | Accuracy Threshold: 0.85 | Bias Threshold: 0.1 =
# ========================================================================================
# Partition 0  | Accuracy: 0.9583 (pass) | Checked: 0.1495
# Partition 1  | Accuracy: 0.9600 (pass) | Checked: 0.1348
# Total Passes | Accuracy: 2/2 	       | Bias passes: 2/2
#
# =======================================================================================
# = Partition Testing Bad Model gender | Accuracy Threshold: 0.85 | Bias Threshold: 0.1 =
# =======================================================================================
# Partition 0  | Accuracy: 0.9824 (pass) | Checked: 0.1510
# Partition 1  | Accuracy: 0.9825 (pass) | Checked: 0.1459
# Total Passes | Accuracy: 2/2 	       | Bias passes: 2/2
#
# ==============================================================================================
# = Partition Testing Good Model relationship | Accuracy Threshold: 0.85 | Bias Threshold: 0.1 =
# ==============================================================================================
# Partition 0  | Accuracy: 0.9619 (pass) | Checked: 0.1266
# Partition 1  | Accuracy: 0.9531 (pass) | Checked: 0.1772
# Partition 2  | Accuracy: nan (fail) | Checked: nan
# Total Passes | Accuracy: 2/3 	       | Bias passes: 0/3
#
# =============================================================================================
# = Partition Testing Bad Model relationship | Accuracy Threshold: 0.85 | Bias Threshold: 0.1 =
# =============================================================================================
# Partition 0  | Accuracy: 0.9840 (pass) | Checked: 0.1256
# Partition 1  | Accuracy: 0.9789 (pass) | Checked: 0.1992
# Partition 2  | Accuracy: nan (fail) | Checked: nan
# Total Passes | Accuracy: 2/3 	       | Bias passes: 0/3
#
# =====================================================================================
# = Partition Testing Good Model age | Accuracy Threshold: 0.85 | Bias Threshold: 0.1 =
# =====================================================================================
# Partition 0  | Accuracy: 0.9588 (pass) | Checked: 0.0804
# Partition 1  | Accuracy: nan (fail) | Checked: nan
# Partition 2  | Accuracy: nan (fail) | Checked: nan
# Total Passes | Accuracy: 1/3 	       | Bias passes: 0/3
#
# ====================================================================================
# = Partition Testing Bad Model age | Accuracy Threshold: 0.85 | Bias Threshold: 0.1 =
# ====================================================================================
# Partition 0  | Accuracy: 0.9843 (pass) | Checked: 0.0896
# Partition 1  | Accuracy: nan (fail) | Checked: nan
# Partition 2  | Accuracy: nan (fail) | Checked: nan
# Total Passes | Accuracy: 1/3 	       | Bias passes: 0/3
#
# ============================================================================================
# = Partition Testing Good Model irrelevant | Accuracy Threshold: 0.85 | Bias Threshold: 0.1 =
# ============================================================================================
# Partition 0  | Accuracy: 0.9571 (pass) | Checked: 0.1384
# Partition 1  | Accuracy: 0.9622 (pass) | Checked: 0.1485
# Total Passes | Accuracy: 2/2 	       | Bias passes: 2/2
#
# ===========================================================================================
# = Partition Testing Bad Model irrelevant | Accuracy Threshold: 0.85 | Bias Threshold: 0.1 =
# ===========================================================================================
# Partition 0  | Accuracy: 0.9821 (pass) | Checked: 0.1466
# Partition 1  | Accuracy: 0.9831 (pass) | Checked: 0.1515
# Total Passes | Accuracy: 2/2 	       | Bias passes: 2/2
#
# =====================================================
# = Test Target | # of Tests | Good Model | Bad Model =
# =====================================================
# Accuracy      | 21	   | 17		| 17
# Bias          | 21	   | 4		| 4

# %% [markdown]
# ### Shuffle Testing

# %%
def shuffle_test( model, X, y, columns, title, tries=5, accuracy_threshold=0.9, bias_threshold=0.05 ):
    passes, accuracy_passes = 0, 0
    checked_per_try = np.empty( tries )
    y_pred_orig = model.predict( X )

    title_string = f"= Partition Testing {title} | Accuracy Threshold: {style.bold}{accuracy_threshold}{style.reset} | Bias Threshold: {style.bold}{bias_threshold}{style.reset} ="
    dashes = len(title_string) - 38
    print( "="*dashes )
    print( title_string )
    print( "="*dashes )
    for idx in range(tries):
        X_alt = shuffle_columns( X, columns )
        y_pred = model.predict( X_alt )

        accuracy = (y_pred==y).mean()
        changed_count = ( y_pred != y_pred_orig ).mean()

        if accuracy >= accuracy_threshold:
            accuracy_passes += 1
        if changed_count < bias_threshold:
            passes += 1

        print( f"Test {idx} | "
               f"Accuracy: {accuracy:.4f} ({ fg.green + 'pass' + style.reset if accuracy >= accuracy_threshold else fg.red + 'fail' + style.reset }) | "
               f"Changed: {changed_count:.4f} ({ fg.green + 'pass' + style.reset if changed_count < bias_threshold else fg.red + 'fail' + style.reset })"
             )

    print( f"Total Passes |"
        f" Accuracy: {accuracy_passes}/{tries} |"
        f" Bias passes: {passes}/{tries}\n" )

    return {
        'bias_passes': passes,
        'accuracy_passes': accuracy_passes,
        'tests': tries
    }

# %%
def shuffle_tests( model1, model2, title1, title2 ):
    m1_results = { 'title': title1, 'bias_passes': 0, 'accuracy_passes': 0, 'tests': 0 }
    m2_results = { 'title': title2, 'bias_passes': 0, 'accuracy_passes': 0, 'tests': 0 }

    BIAS_THRESH = 0.05
    TRIES = 5
    
    for problem_type in problem_cols:
        set_title = fg.gray + problem_type + fg.reset
        results = shuffle_test( model=model1, X=features, y=target, columns=problem_cols[problem_type],
                                   title=f"{title1} {set_title}", tries=TRIES, accuracy_threshold=ACC_THRESH, bias_threshold=BIAS_THRESH )
        m1_results['bias_passes'] += results['bias_passes']
        m1_results['accuracy_passes'] += results['accuracy_passes']
        m1_results['tests'] += results['tests']
        
        results = shuffle_test( model=model2, X=features, y=target, columns=problem_cols[problem_type],
                                   title=f"{title2} {set_title}", tries=TRIES, accuracy_threshold=ACC_THRESH, bias_threshold=BIAS_THRESH )
        m2_results['bias_passes'] += results['bias_passes']
        m2_results['accuracy_passes'] += results['accuracy_passes']
        m2_results['tests'] += results['tests']
        
    aggregate_results( m1_results, m2_results )

# %% [markdown]
# #### Results

# %%
shuffle_tests( good_model, bad_model, GOOD_TITLE, BAD_TITLE )
# Out:
# ================================================================================================
# = Partition Testing Good Model psychological | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ================================================================================================
# Test 0 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 1 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 2 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 3 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 4 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# ===============================================================================================
# = Partition Testing Bad Model psychological | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ===============================================================================================
# Test 0 | Accuracy: 0.9792 (pass) | Changed: 0.0066 (pass)
# Test 1 | Accuracy: 0.9791 (pass) | Changed: 0.0068 (pass)
# Test 2 | Accuracy: 0.9791 (pass) | Changed: 0.0067 (pass)
# Test 3 | Accuracy: 0.9790 (pass) | Changed: 0.0068 (pass)
# Test 4 | Accuracy: 0.9789 (pass) | Changed: 0.0070 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# ==========================================================================================
# = Partition Testing Good Model medical | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ==========================================================================================
# Test 0 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 1 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 2 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 3 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 4 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# =========================================================================================
# = Partition Testing Bad Model medical | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =========================================================================================
# Test 0 | Accuracy: 0.9390 (pass) | Changed: 0.0521 (fail)
# Test 1 | Accuracy: 0.9385 (pass) | Changed: 0.0522 (fail)
# Test 2 | Accuracy: 0.9399 (pass) | Changed: 0.0511 (fail)
# Test 3 | Accuracy: 0.9390 (pass) | Changed: 0.0523 (fail)
# Test 4 | Accuracy: 0.9401 (pass) | Changed: 0.0514 (fail)
# Total Passes | Accuracy: 5/5 | Bias passes: 0/5
#
# =========================================================================================
# = Partition Testing Good Model racial | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =========================================================================================
# Test 0 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 1 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 2 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 3 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 4 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# ========================================================================================
# = Partition Testing Bad Model racial | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ========================================================================================
# Test 0 | Accuracy: 0.9340 (pass) | Changed: 0.0590 (fail)
# Test 1 | Accuracy: 0.9346 (pass) | Changed: 0.0579 (fail)
# Test 2 | Accuracy: 0.9339 (pass) | Changed: 0.0586 (fail)
# Test 3 | Accuracy: 0.9346 (pass) | Changed: 0.0586 (fail)
# Test 4 | Accuracy: 0.9354 (pass) | Changed: 0.0569 (fail)
# Total Passes | Accuracy: 5/5 | Bias passes: 0/5
#
# =============================================================================================
# = Partition Testing Good Model subjective | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =============================================================================================
# Test 0 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 1 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 2 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 3 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 4 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# ============================================================================================
# = Partition Testing Bad Model subjective | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ============================================================================================
# Test 0 | Accuracy: 0.9441 (pass) | Changed: 0.0466 (pass)
# Test 1 | Accuracy: 0.9462 (pass) | Changed: 0.0455 (pass)
# Test 2 | Accuracy: 0.9448 (pass) | Changed: 0.0460 (pass)
# Test 3 | Accuracy: 0.9452 (pass) | Changed: 0.0460 (pass)
# Test 4 | Accuracy: 0.9447 (pass) | Changed: 0.0467 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# =========================================================================================
# = Partition Testing Good Model gender | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =========================================================================================
# Test 0 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 1 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 2 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 3 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 4 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# ========================================================================================
# = Partition Testing Bad Model gender | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ========================================================================================
# Test 0 | Accuracy: 0.9786 (pass) | Changed: 0.0063 (pass)
# Test 1 | Accuracy: 0.9790 (pass) | Changed: 0.0059 (pass)
# Test 2 | Accuracy: 0.9787 (pass) | Changed: 0.0062 (pass)
# Test 3 | Accuracy: 0.9785 (pass) | Changed: 0.0063 (pass)
# Test 4 | Accuracy: 0.9787 (pass) | Changed: 0.0062 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# ===============================================================================================
# = Partition Testing Good Model relationship | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ===============================================================================================
# Test 0 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 1 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 2 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 3 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 4 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# ==============================================================================================
# = Partition Testing Bad Model relationship | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ==============================================================================================
# Test 0 | Accuracy: 0.8931 (pass) | Changed: 0.1015 (fail)
# Test 1 | Accuracy: 0.8945 (pass) | Changed: 0.1002 (fail)
# Test 2 | Accuracy: 0.8938 (pass) | Changed: 0.1004 (fail)
# Test 3 | Accuracy: 0.8940 (pass) | Changed: 0.1004 (fail)
# Test 4 | Accuracy: 0.8933 (pass) | Changed: 0.1008 (fail)
# Total Passes | Accuracy: 5/5 | Bias passes: 0/5
#
# ======================================================================================
# = Partition Testing Good Model age | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ======================================================================================
# Test 0 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 1 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 2 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 3 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 4 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# =====================================================================================
# = Partition Testing Bad Model age | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =====================================================================================
# Test 0 | Accuracy: 0.9406 (pass) | Changed: 0.0492 (pass)
# Test 1 | Accuracy: 0.9397 (pass) | Changed: 0.0498 (pass)
# Test 2 | Accuracy: 0.9406 (pass) | Changed: 0.0495 (pass)
# Test 3 | Accuracy: 0.9409 (pass) | Changed: 0.0492 (pass)
# Test 4 | Accuracy: 0.9397 (pass) | Changed: 0.0501 (fail)
# Total Passes | Accuracy: 5/5 | Bias passes: 4/5
#
# =============================================================================================
# = Partition Testing Good Model irrelevant | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =============================================================================================
# Test 0 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 1 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 2 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 3 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 4 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# ============================================================================================
# = Partition Testing Bad Model irrelevant | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ============================================================================================
# Test 0 | Accuracy: 0.9820 (pass) | Changed: 0.0017 (pass)
# Test 1 | Accuracy: 0.9821 (pass) | Changed: 0.0017 (pass)
# Test 2 | Accuracy: 0.9820 (pass) | Changed: 0.0018 (pass)
# Test 3 | Accuracy: 0.9819 (pass) | Changed: 0.0019 (pass)
# Test 4 | Accuracy: 0.9820 (pass) | Changed: 0.0018 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# =====================================================
# = Test Target | # of Tests | Good Model | Bad Model =
# =====================================================
# Accuracy      | 40	   | 40		| 40
# Bias          | 40	   | 40		| 24

# %% [markdown]
# ### Flip Testing

# %%
def flip_test( model, X, y, columns, title, accuracy_threshold=0.9, bias_threshold=0.05 ):
    passes, accuracy_passes = 0, 0
    y_pred_orig = model.predict( X )

    title_string = f"= Partition Testing {title} | Accuracy Threshold: {style.bold}{accuracy_threshold}{style.reset} | Bias Threshold: {style.bold}{bias_threshold}{style.reset} ="
    dashes = len(title_string) - 38
    print( "="*dashes )
    print( title_string )
    print( "="*dashes )
    X_alt = flip_columns( X, columns )
    y_pred = model.predict( X_alt )
    accuracy = (y_pred==y).mean()
    accuracy_passes = 1 if accuracy > accuracy_threshold else 0

    changed_count = ( y_pred != y_pred_orig ).mean()
    passes = 1 if changed_count < bias_threshold else 0
    print( f"Result | "
           f"Accuracy: {accuracy:.4f} ({ fg.green + 'pass' + style.reset if accuracy_passes==1 else fg.red + 'fail' + style.reset }) | "
           f"Changed: {changed_count:.4f} ({ fg.green + 'pass' + style.reset if passes==1 else fg.red + 'fail' + style.reset })\n"
         )

    return {
        'bias_passes': passes,
        'accuracy_passes': accuracy_passes,
        'tests': 1
    }

# %%
def flip_tests( model1, model2, title1, title2 ):
    m1_results = { 'title': title1, 'bias_passes': 0, 'accuracy_passes': 0, 'tests': 0 }
    m2_results = { 'title': title2, 'bias_passes': 0, 'accuracy_passes': 0, 'tests': 0 }

    BIAS_THRESH = 0.05
    
    for problem_type in problem_cols:
        set_title = fg.gray + problem_type + fg.reset
        results = flip_test( model=model1, X=features, y=target, columns=problem_cols[problem_type],
                                title=f"{title1} {set_title}", accuracy_threshold=ACC_THRESH, bias_threshold=BIAS_THRESH )
        m1_results['bias_passes'] += results['bias_passes']
        m1_results['accuracy_passes'] += results['accuracy_passes']
        m1_results['tests'] += results['tests']
        
        results = flip_test( model=model2, X=features, y=target, columns=problem_cols[problem_type],
                                title=f"{title2} {set_title}", accuracy_threshold=ACC_THRESH, bias_threshold=BIAS_THRESH )
        m2_results['bias_passes'] += results['bias_passes']
        m2_results['accuracy_passes'] += results['accuracy_passes']
        m2_results['tests'] += results['tests']
        
    aggregate_results( m1_results, m2_results )

# %% [markdown]
# #### Results

# %%
flip_tests( good_model, bad_model, GOOD_TITLE, BAD_TITLE )
# Out:
# ================================================================================================
# = Partition Testing Good Model psychological | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ================================================================================================
# Result | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
#
# ===============================================================================================
# = Partition Testing Bad Model psychological | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ===============================================================================================
# Result | Accuracy: 0.9661 (pass) | Changed: 0.0226 (pass)
#
# ==========================================================================================
# = Partition Testing Good Model medical | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ==========================================================================================
# Result | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
#
# =========================================================================================
# = Partition Testing Bad Model medical | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =========================================================================================
# Result | Accuracy: 0.8861 (pass) | Changed: 0.1104 (fail)
#
# =========================================================================================
# = Partition Testing Good Model racial | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =========================================================================================
# Result | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
#
# ========================================================================================
# = Partition Testing Bad Model racial | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ========================================================================================
# Result | Accuracy: 0.8676 (pass) | Changed: 0.1305 (fail)
#
# =============================================================================================
# = Partition Testing Good Model subjective | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =============================================================================================
# Result | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
#
# ============================================================================================
# = Partition Testing Bad Model subjective | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ============================================================================================
# Result | Accuracy: 0.8953 (pass) | Changed: 0.1014 (fail)
#
# =========================================================================================
# = Partition Testing Good Model gender | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =========================================================================================
# Result | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
#
# ========================================================================================
# = Partition Testing Bad Model gender | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ========================================================================================
# Result | Accuracy: 0.9749 (pass) | Changed: 0.0121 (pass)
#
# ===============================================================================================
# = Partition Testing Good Model relationship | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ===============================================================================================
# Result | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
#
# ==============================================================================================
# = Partition Testing Bad Model relationship | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ==============================================================================================
# Result | Accuracy: 0.6353 (fail) | Changed: 0.3634 (fail)
#
# ======================================================================================
# = Partition Testing Good Model age | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ======================================================================================
# Result | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
#
# =====================================================================================
# = Partition Testing Bad Model age | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =====================================================================================
# Result | Accuracy: 0.9275 (pass) | Changed: 0.0641 (fail)
#
# =============================================================================================
# = Partition Testing Good Model irrelevant | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =============================================================================================
# Result | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
#
# ============================================================================================
# = Partition Testing Bad Model irrelevant | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ============================================================================================
# Result | Accuracy: 0.9815 (pass) | Changed: 0.0036 (pass)
#
# =====================================================
# = Test Target | # of Tests | Good Model | Bad Model =
# =====================================================
# Accuracy      | 8	   | 8		| 7
# Bias          | 8	   | 8		| 3

# %% [markdown]
# ### Noise Test

# %%
def noise_test( model, X, y, columns, title, tries=5, accuracy_threshold=0.9, bias_threshold=0.05 ):
    passes, accuracy_passes = 0, 0
    checked_per_try = np.empty( tries )
    y_pred_orig = model.predict( X )

    title_string = f"= Noise Testing {title} | Accuracy Threshold: {style.bold}{accuracy_threshold}{style.reset} | Bias Threshold: {style.bold}{bias_threshold}{style.reset} ="
    dashes = len(title_string) - 38
    print( "="*dashes )
    print( title_string )
    print( "="*dashes )
    for idx in range(tries):
        X_alt = add_noise_to_columns( X, columns, noise_scale=2.0 )
        y_pred = model.predict( X_alt )

        accuracy = (y_pred==y).mean()
        changed_count = ( y_pred != y_pred_orig ).mean()

        if accuracy >= accuracy_threshold:
            accuracy_passes += 1
        if changed_count < bias_threshold:
            passes += 1

        print( f"Test {idx} | "
               f"Accuracy: {accuracy:.4f} ({ fg.green + 'pass' + style.reset if accuracy >= accuracy_threshold else fg.red + 'fail' + style.reset }) | "
               f"Changed: {changed_count:.4f} ({ fg.green + 'pass' + style.reset if changed_count < bias_threshold else fg.red + 'fail' + style.reset })"
             )

    print( f"Total Passes |"
        f" Accuracy: {accuracy_passes}/{tries} |"
        f" Bias passes: {passes}/{tries}\n" )

    return {
        'bias_passes': passes,
        'accuracy_passes': accuracy_passes,
        'tests': tries
    }

# %%
def noise_tests( model1, model2, title1, title2 ):
    m1_results = { 'title': title1, 'bias_passes': 0, 'accuracy_passes': 0, 'tests': 0 }
    m2_results = { 'title': title2, 'bias_passes': 0, 'accuracy_passes': 0, 'tests': 0 }

    BIAS_THRESH = 0.05
    TRIES = 5
    
    for problem_type in problem_cols:
        set_title = fg.gray + problem_type + fg.reset
        results = noise_test( model=model1, X=features, y=target, columns=problem_cols[problem_type],
                                 title=f"{title1} {set_title}", tries=TRIES, accuracy_threshold=ACC_THRESH, bias_threshold=BIAS_THRESH )
        m1_results['bias_passes'] += results['bias_passes']
        m1_results['accuracy_passes'] += results['accuracy_passes']
        m1_results['tests'] += results['tests']
        
        results = noise_test( model=model2, X=features, y=target, columns=problem_cols[problem_type],
                                 title=f"{title2} {set_title}", tries=TRIES, accuracy_threshold=ACC_THRESH, bias_threshold=BIAS_THRESH )
        m2_results['bias_passes'] += results['bias_passes']
        m2_results['accuracy_passes'] += results['accuracy_passes']
        m2_results['tests'] += results['tests']
        
    aggregate_results( m1_results, m2_results )

# %% [markdown]
# #### Results

# %%
noise_tests( good_model, bad_model, GOOD_TITLE, BAD_TITLE )
# Out:
# ============================================================================================
# = Noise Testing Good Model psychological | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ============================================================================================
# Test 0 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 1 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 2 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 3 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 4 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# ===========================================================================================
# = Noise Testing Bad Model psychological | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ===========================================================================================
# Test 0 | Accuracy: 0.9736 (pass) | Changed: 0.0133 (pass)
# Test 1 | Accuracy: 0.9733 (pass) | Changed: 0.0138 (pass)
# Test 2 | Accuracy: 0.9732 (pass) | Changed: 0.0136 (pass)
# Test 3 | Accuracy: 0.9733 (pass) | Changed: 0.0139 (pass)
# Test 4 | Accuracy: 0.9737 (pass) | Changed: 0.0134 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# ======================================================================================
# = Noise Testing Good Model medical | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ======================================================================================
# Test 0 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 1 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 2 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 3 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 4 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# =====================================================================================
# = Noise Testing Bad Model medical | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =====================================================================================
# Test 0 | Accuracy: 0.9230 (pass) | Changed: 0.0696 (fail)
# Test 1 | Accuracy: 0.9230 (pass) | Changed: 0.0692 (fail)
# Test 2 | Accuracy: 0.9216 (pass) | Changed: 0.0710 (fail)
# Test 3 | Accuracy: 0.9232 (pass) | Changed: 0.0691 (fail)
# Test 4 | Accuracy: 0.9229 (pass) | Changed: 0.0694 (fail)
# Total Passes | Accuracy: 5/5 | Bias passes: 0/5
#
# =====================================================================================
# = Noise Testing Good Model racial | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =====================================================================================
# Test 0 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 1 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 2 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 3 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 4 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# ====================================================================================
# = Noise Testing Bad Model racial | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ====================================================================================
# Test 0 | Accuracy: 0.9098 (pass) | Changed: 0.0853 (fail)
# Test 1 | Accuracy: 0.9098 (pass) | Changed: 0.0851 (fail)
# Test 2 | Accuracy: 0.9114 (pass) | Changed: 0.0839 (fail)
# Test 3 | Accuracy: 0.9100 (pass) | Changed: 0.0852 (fail)
# Test 4 | Accuracy: 0.9100 (pass) | Changed: 0.0850 (fail)
# Total Passes | Accuracy: 5/5 | Bias passes: 0/5
#
# =========================================================================================
# = Noise Testing Good Model subjective | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =========================================================================================
# Test 0 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 1 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 2 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 3 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 4 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# ========================================================================================
# = Noise Testing Bad Model subjective | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ========================================================================================
# Test 0 | Accuracy: 0.9320 (pass) | Changed: 0.0615 (fail)
# Test 1 | Accuracy: 0.9313 (pass) | Changed: 0.0619 (fail)
# Test 2 | Accuracy: 0.9313 (pass) | Changed: 0.0617 (fail)
# Test 3 | Accuracy: 0.9317 (pass) | Changed: 0.0614 (fail)
# Test 4 | Accuracy: 0.9314 (pass) | Changed: 0.0617 (fail)
# Total Passes | Accuracy: 5/5 | Bias passes: 0/5
#
# =====================================================================================
# = Noise Testing Good Model gender | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =====================================================================================
# Test 0 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 1 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 2 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 3 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 4 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# ====================================================================================
# = Noise Testing Bad Model gender | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ====================================================================================
# Test 0 | Accuracy: 0.9751 (pass) | Changed: 0.0109 (pass)
# Test 1 | Accuracy: 0.9748 (pass) | Changed: 0.0112 (pass)
# Test 2 | Accuracy: 0.9746 (pass) | Changed: 0.0115 (pass)
# Test 3 | Accuracy: 0.9747 (pass) | Changed: 0.0111 (pass)
# Test 4 | Accuracy: 0.9751 (pass) | Changed: 0.0109 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# ===========================================================================================
# = Noise Testing Good Model relationship | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ===========================================================================================
# Test 0 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 1 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 2 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 3 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 4 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# ==========================================================================================
# = Noise Testing Bad Model relationship | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ==========================================================================================
# Test 0 | Accuracy: 0.8998 (pass) | Changed: 0.0959 (fail)
# Test 1 | Accuracy: 0.9008 (pass) | Changed: 0.0948 (fail)
# Test 2 | Accuracy: 0.8998 (pass) | Changed: 0.0954 (fail)
# Test 3 | Accuracy: 0.8996 (pass) | Changed: 0.0958 (fail)
# Test 4 | Accuracy: 0.8996 (pass) | Changed: 0.0952 (fail)
# Total Passes | Accuracy: 5/5 | Bias passes: 0/5
#
# ==================================================================================
# = Noise Testing Good Model age | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ==================================================================================
# Test 0 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 1 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 2 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 3 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 4 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# =================================================================================
# = Noise Testing Bad Model age | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =================================================================================
# Test 0 | Accuracy: 0.8524 (pass) | Changed: 0.1387 (fail)
# Test 1 | Accuracy: 0.8538 (pass) | Changed: 0.1377 (fail)
# Test 2 | Accuracy: 0.8521 (pass) | Changed: 0.1395 (fail)
# Test 3 | Accuracy: 0.8512 (pass) | Changed: 0.1403 (fail)
# Test 4 | Accuracy: 0.8510 (pass) | Changed: 0.1406 (fail)
# Total Passes | Accuracy: 5/5 | Bias passes: 0/5
#
# =========================================================================================
# = Noise Testing Good Model irrelevant | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# =========================================================================================
# Test 0 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 1 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 2 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 3 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Test 4 | Accuracy: 0.9591 (pass) | Changed: 0.0000 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# ========================================================================================
# = Noise Testing Bad Model irrelevant | Accuracy Threshold: 0.85 | Bias Threshold: 0.05 =
# ========================================================================================
# Test 0 | Accuracy: 0.9798 (pass) | Changed: 0.0050 (pass)
# Test 1 | Accuracy: 0.9797 (pass) | Changed: 0.0050 (pass)
# Test 2 | Accuracy: 0.9797 (pass) | Changed: 0.0052 (pass)
# Test 3 | Accuracy: 0.9798 (pass) | Changed: 0.0050 (pass)
# Test 4 | Accuracy: 0.9801 (pass) | Changed: 0.0050 (pass)
# Total Passes | Accuracy: 5/5 | Bias passes: 5/5
#
# =====================================================
# = Test Target | # of Tests | Good Model | Bad Model =
# =====================================================
# Accuracy      | 40	   | 40		| 40
# Bias          | 40	   | 40		| 15

# %%
def data_leakage_test( model, X, y, columns, title, tries=5, accuracy_threshold=0.9, bias_threshold=0.05 ):
    with torch.no_grad

# %% [markdown]
# ### Group 2 Tests

# %%
class SklearnModel:
    def __init__( self, filename ):
        self.session = rt.InferenceSession(filename)

    def predict( self, X ):
        return self.session.run(None, {'X': X.values.astype(np.float32)})[0]

model1 = SklearnModel("models/model1_1.onnx")
model2 = SklearnModel("models/model1_2.onnx")

M1_TITLE = fg.cyan + "Model A" + style.reset
M2_TITLE = fg.cyan + "Model B" + style.reset

# %%
partition_tests( model1, model2, M1_TITLE, M2_TITLE )
# Out:
# ===========================================================================================
# = Partition Testing Model A psychological | Accuracy Threshold: 0.85 | Bias Threshold: 0.1 =
# ===========================================================================================
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 partition_tests( model1, model2, M1_TITLE, M2_TITLE )
#
# Cell In[22], line 9, in partition_tests(model1, model2, title1, title2)
#       7 for partition_name in partitions:
#       8     set_title = fg.gray + partition_name + fg.reset
# ----> 9     results = partition_test( model=model1, X=features, y=target, partitions=partitions[partition_name],
#      10                                title=f"{title1} {set_title}", accuracy_threshold=ACC_THRESH, bias_threshold=BIAS_THRESH )
#      11     m1_results['bias_passes'] += results['bias_passes']
#      12     m1_results['accuracy_passes'] += results['accuracy_passes']
#
# Cell In[21], line 14, in partition_test(model, X, y, partitions, title, accuracy_threshold, bias_threshold)
#      11 X_part = X.iloc[partition[0]]
#      12 y_part = y.iloc[partition[0]]
# ---> 14 y_pred = model.predict(X_part)
#      15 accuracy = (y_pred==y_part).mean()
#      16 if accuracy > accuracy_threshold:
#
# Cell In[33], line 6, in SklearnModel.predict(self, X)
#       5 def predict( self, X ):
# ----> 6     return self.session.run(None, {'X': X.values.astype(np.float32)})[0]
#
# File ~/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:283, in Session.run(self, output_names, input_feed, run_options)
#     269 def run(self, output_names, input_feed, run_options=None) -> Sequence[np.ndarray | SparseTensor | list | dict]:
#     270     """
#     271     Compute the predictions.
#     272
#    (...)    281         sess.run([output_name], {input_name: x})
#     282     """
# --> 283     self._validate_input(list(input_feed.keys()))
#     284     if not output_names:
#     285         output_names = [output.name for output in self._outputs_meta]
#
# File ~/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:265, in Session._validate_input(self, feed_input_names)
#     263         missing_input_names.append(input.name)
#     264 if missing_input_names:
# --> 265     raise ValueError(
#     266         f"Required inputs ({missing_input_names}) are missing from input feed ({feed_input_names})."
#     267     )
#
# ValueError: Required inputs (['input']) are missing from input feed (['X']).

# %%
shuffle_tests( model1, model2, M1_TITLE, M2_TITLE )

# %%
flip_tests( model1, model2, M1_TITLE, M2_TITLE )

# %%
noise_tests( model1, model2, M1_TITLE, M2_TITLE )
