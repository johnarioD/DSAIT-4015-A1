# %% [markdown]
# # Part 1

# %%
from data_handling import get_testing_data
from outlier_detection import identify_outliers
from prediction_models import get_trained_models, SklearnModel
from metamorphic_suite import MetamorphicSuite, shuffle_columns, flip_columns, add_noise_to_columns
from partition_suite import PartitionSuite
from metrics import ACCURACY_METRIC, CHANGE_RATE, DIVERGENCE_FROM_MEAN
from term_styling import style, fg, bg

features, target, problem_cols = get_testing_data()

# %% [markdown]
# ## Outlier Detection

# %%
identify_outliers( features, features.columns, 2 )
# Out:
# Dataset Outlier Test - 2 Sigma
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Adres_aantal_brp_adres:                                                                                                  Low:	0	High:	7465
# Adres_aantal_verschillende_wijken:                                                                                       Low:	0	High:	9793
# Adres_aantal_verzendadres:                                                                                               Low:	0	High:	2051
# Adres_aantal_woonadres_handmatig:                                                                                        Low:	0	High:	3965
# Adres_dagen_op_adres:                                                                                                    Low:	0	High:	3618
# ...

# %%
identify_outliers( features, features.columns, 4 )
# Out:
# Dataset Outlier Test - 4 Sigma
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Adres_aantal_brp_adres:                                                                                                  Low:	0	High:	214
# Adres_aantal_verschillende_wijken:                                                                                       Low:	0	High:	205
# Adres_aantal_verzendadres:                                                                                               Low:	0	High:	9
# Adres_aantal_woonadres_handmatig:                                                                                        Low:	0	High:	46
# Adres_recentst_onderdeel_rdam:                                                                                           Low:	6426	High:	0
# ...

# %% [markdown]
# # Part 3

# %% [markdown]
# ## Training

# %%
GOOD_TITLE = fg.green + "Good Model" + fg.reset
BAD_TITLE = fg.red + "Bad Model" + fg.reset
titles = [GOOD_TITLE, BAD_TITLE]

models = get_trained_models(features, target, problem_cols['full'])
# Out:
# /home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/prediction_models.py:93: UserWarning: # 'dynamic_axes' is not recommended when dynamo=True, and may lead to 'torch._dynamo.exc.UserError: Constraints violated.' Supply the 'dynamic_shapes' argument instead if export is unsuccessful.
#   torch.onnx.export(
# W0201 18:27:19.976000 29928 torch/onnx/_internal/exporter/_compat.py:125] Setting ONNX exporter to use operator set version 18 because the requested opset_version 12 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# ...

# %% [markdown]
# ## Testing

# %% [markdown]
# ### Partition Testing

# %%
partition_suite = PartitionSuite( problem_cols, ACCURACY_METRIC, DIVERGENCE_FROM_MEAN, verbosity=1 )

partition_suite.run( models, titles, features, target )
# Out:
# /home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/metrics.py:19: RuntimeWarning: invalid value encountered in divide
#   return np.abs( X / X.mean() - 1 )
# Partition Testing Results Good Model psychological	| Accuracy: 2/2 | Mean Div: 0/2
# Partition Testing Results Good Model medical	| Accuracy: 2/2 | Mean Div: 0/2
# Partition Testing Results Good Model racial	| Accuracy: 4/4 | Mean Div: 0/4
# Partition Testing Results Good Model subjective	| Accuracy: 3/3 | Mean Div: 0/3
# Partition Testing Results Good Model gender	| Accuracy: 2/2 | Mean Div: 0/2
# Partition Testing Results Good Model relationship	| Accuracy: 3/3 | Mean Div: 0/3
# Partition Testing Results Good Model age	| Accuracy: 2/3 | Mean Div: 0/3
# Partition Testing Results Good Model irrelevant	| Accuracy: 2/2 | Mean Div: 0/2
# Partition Testing Results Bad Model psychological	| Accuracy: 2/2 | Mean Div: 0/2
# ...

# %% [markdown]
# ### Shuffle Testing

# %%
shuffle_suite = MetamorphicSuite( shuffle_columns, "Shuffle", 5, problem_cols, ACCURACY_METRIC, CHANGE_RATE, verbosity=1 )

shuffle_suite.run( models, titles, features, target )
# Out:
# Shuffle Testing Results Good Model psychological	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Good Model medical	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Good Model racial	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Good Model subjective	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Good Model gender	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Good Model relationship	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Good Model age	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Good Model irrelevant	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Bad Model psychological	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Bad Model medical	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Bad Model racial	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Bad Model subjective	| Accuracy: 5/5 | Changed: 5/5
# ...

# %% [markdown]
# ### Flip Testing

# %%
flip_suite = MetamorphicSuite( flip_columns, "Flip", 1, problem_cols, ACCURACY_METRIC, CHANGE_RATE, verbosity=1 )

flip_suite.run( models, titles, features, target )
# Out:
# Flip Testing Results Good Model psychological	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Good Model medical	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Good Model racial	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Good Model subjective	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Good Model gender	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Good Model relationship	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Good Model age	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Good Model irrelevant	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Bad Model psychological	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Bad Model medical	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Bad Model racial	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Bad Model subjective	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Bad Model gender	| Accuracy: 1/1 | Changed: 1/1
# ...

# %% [markdown]
# ### Noise Test

# %%
noise_suite = MetamorphicSuite( add_noise_to_columns, "Noise", 5, problem_cols, ACCURACY_METRIC, CHANGE_RATE, verbosity=1 )

noise_suite.run( models, titles, features, target )
# Out:
# Noise Testing Results Good Model psychological	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Good Model medical	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Good Model racial	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Good Model subjective	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Good Model gender	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Good Model relationship	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Good Model age	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Good Model irrelevant	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Bad Model psychological	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Bad Model medical	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Bad Model racial	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Bad Model subjective	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Bad Model gender	| Accuracy: 5/5 | Changed: 5/5
# ...

# %% [markdown]
# ### Group 2 Tests

# %%
model1 = SklearnModel("models/model1_1.onnx")
model2 = SklearnModel("models/model1_2.onnx")

M1_TITLE = fg.cyan + "Model A" + style.reset
M2_TITLE = fg.purple + "Model B" + style.reset

models = [model1,model2]
titles = [M1_TITLE,M2_TITLE]

# %%
partition_suite.run( models, titles, features, target )
# Out:
# Partition Testing Results Model A psychological	| Accuracy: 2/2 | Mean Div: 2/2
# Partition Testing Results Model A medical	| Accuracy: 2/2 | Mean Div: 0/2
# Partition Testing Results Model A racial	| Accuracy: 4/4 | Mean Div: 0/4
# Partition Testing Results Model A subjective	| Accuracy: 3/3 | Mean Div: 0/3
# Partition Testing Results Model A gender	| Accuracy: 2/2 | Mean Div: 0/2
# Partition Testing Results Model A relationship	| Accuracy: 3/3 | Mean Div: 0/3
# Partition Testing Results Model A age	| Accuracy: 2/3 | Mean Div: 0/3
# Partition Testing Results Model A irrelevant	| Accuracy: 2/2 | Mean Div: 0/2
# Partition Testing Results Model B psychological	| Accuracy: 2/2 | Mean Div: 0/2
# Partition Testing Results Model B medical	| Accuracy: 2/2 | Mean Div: 0/2
# Partition Testing Results Model B racial	| Accuracy: 4/4 | Mean Div: 1/4
# Partition Testing Results Model B subjective	| Accuracy: 3/3 | Mean Div: 0/3
# ...

# %%
shuffle_suite.run( models, titles, features, target )
# Out:
# Shuffle Testing Results Model A psychological	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Model A medical	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Model A racial	| Accuracy: 5/5 | Changed: 0/5
# Shuffle Testing Results Model A subjective	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Model A gender	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Model A relationship	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Model A age	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Model A irrelevant	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Model B psychological	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Model B medical	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Model B racial	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Model B subjective	| Accuracy: 5/5 | Changed: 5/5
# Shuffle Testing Results Model B gender	| Accuracy: 5/5 | Changed: 5/5
# ...

# %%
flip_suite.run( models, titles, features, target )
# Out:
# Flip Testing Results Model A psychological	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Model A medical	| Accuracy: 1/1 | Changed: 0/1
# Flip Testing Results Model A racial	| Accuracy: 1/1 | Changed: 0/1
# Flip Testing Results Model A subjective	| Accuracy: 1/1 | Changed: 0/1
# Flip Testing Results Model A gender	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Model A relationship	| Accuracy: 1/1 | Changed: 0/1
# Flip Testing Results Model A age	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Model A irrelevant	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Model B psychological	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Model B medical	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Model B racial	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Model B subjective	| Accuracy: 1/1 | Changed: 1/1
# Flip Testing Results Model B gender	| Accuracy: 1/1 | Changed: 1/1
# ...

# %%
noise_suite.run( models, titles, features, target )
# Out:
# Noise Testing Results Model A psychological	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Model A medical	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Model A racial	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Model A subjective	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Model A gender	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Model A relationship	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Model A age	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Model A irrelevant	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Model B psychological	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Model B medical	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Model B racial	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Model B subjective	| Accuracy: 5/5 | Changed: 5/5
# Noise Testing Results Model B gender	| Accuracy: 5/5 | Changed: 5/5
# ...
