# %% [markdown]
# # Part 1 & 2

# %%
from data_handling import get_testing_data
from outlier_detection import identify_outliers
from prediction_models import get_trained_models, SklearnModel

from metamorphic_suite import (
	MetamorphicSuite, shuffle_columns, flip_columns, add_noise_to_columns,
	scale_columns, shift_columns, permute_within_quantiles, quantize_columns
)
from partition_suite import PartitionSuite
from boundary_suite import BoundarySuite
from consistency_suite import ConsistencySuite
from monotonicity_suite import MonotonicitySuite
import os

from metrics import (
	STANDARD_PERFORMANCE_METRICS, FAIRNESS_METRICS, ROBUSTNESS_METRICS
)

from term_styling import style, fg, bg

if not os.path.exists('results'):
	os.mkdir('results')
if not os.path.exists('results/group1'):
	os.mkdir('results/group1')
if not os.path.exists('results/group2'):
	os.mkdir('results/group2')

VERBOSITY = 1

features, target, problem_cols = get_testing_data()

# %% [markdown]
# ## Outlier Detection

# %%
identify_outliers( features, features.columns, 2, VERBOSITY )
# Out:
# Dataset Outlier Test - 2 Sigma
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Final Result 76/315 features are found to have significant amounts of outliers.

# %%
identify_outliers( features, features.columns, 3, VERBOSITY )
# Out:
# Dataset Outlier Test - 3 Sigma
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Final Result 17/315 features are found to have significant amounts of outliers.

# %%
identify_outliers( features, features.columns, 4, VERBOSITY )
# Out:
# Dataset Outlier Test - 4 Sigma
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Final Result 4/315 features are found to have significant amounts of outliers.

# %% [markdown]
# # Part 3

# %% [markdown]
# ## Training

# %%
GOOD_TITLE = fg.green + "Good Model" + fg.reset
BAD_TITLE = fg.red + "Bad Model" + fg.reset

models = get_trained_models(features, target, problem_cols['full'])
titles = [GOOD_TITLE, BAD_TITLE]
# Out:
# /home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/prediction_models.py:93: UserWarning: # 'dynamic_axes' is not recommended when dynamo=True, and may lead to 'torch._dynamo.exc.UserError: Constraints violated.' Supply the 'dynamic_shapes' argument instead if export is unsuccessful.
#   torch.onnx.export(
# W0202 09:59:16.070000 2029 torch/onnx/_internal/exporter/_compat.py:125] Setting ONNX exporter to use operator set version 18 because the requested opset_version 12 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# W0202 09:59:16.517000 2029 torch/onnx/_internal/exporter/_registration.py:110] torchvision is not installed. Skipping torchvision::nms
# [torch.onnx] Obtain model graph for `Model([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `Model([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# /usr/lib/python3.11/copyreg.py:105: FutureWarning: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#   return cls.__new__(cls, *args)
# The model version conversion is not supported by the onnxscript version converter and fallback is enabled. The model will be converted using the onnx C API (target version: 12).
# Failed to convert the model to the target version 12 using the ONNX C API. The model was not modified
# Traceback (most recent call last):
#   File "/home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnxscript/version_converter/__init__.py", line 127, in call
#     converted_proto = _c_api_utils.call_onnx_api(
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnxscript/version_converter/_c_api_utils.py", line 65, in call_onnx_api
#     result = func(proto)
#              ^^^^^^^^^^^
#   File "/home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnxscript/version_converter/__init__.py", line 122, in _partial_convert_version
#     return onnx.version_converter.convert_version(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnx/version_converter.py", line 37, in convert_version
#     converted_model_str = C.convert_version(model_str, target_version)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: /github/workspace/onnx/version_converter/BaseConverter.h:73: adapter_lookup: Assertion `false` failed: No Adapter From Version $14 for Relu
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
#
#
# Train Accuracy of the original model: 0.8836346153846154
# Test Accuracy of the original model: 0.8808461538461538
# /home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/prediction_models.py:93: UserWarning: # 'dynamic_axes' is not recommended when dynamo=True, and may lead to 'torch._dynamo.exc.UserError: Constraints violated.' Supply the 'dynamic_shapes' argument instead if export is unsuccessful.
#   torch.onnx.export(
# W0202 09:59:20.482000 2029 torch/onnx/_internal/exporter/_compat.py:125] Setting ONNX exporter to use operator set version 18 because the requested opset_version 12 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# W0202 09:59:20.718000 2029 torch/onnx/_internal/exporter/_registration.py:110] torchvision is not installed. Skipping torchvision::nms
# [torch.onnx] Obtain model graph for `Model([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `Model([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# /usr/lib/python3.11/copyreg.py:105: FutureWarning: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#   return cls.__new__(cls, *args)
# The model version conversion is not supported by the onnxscript version converter and fallback is enabled. The model will be converted using the onnx C API (target version: 12).
# Failed to convert the model to the target version 12 using the ONNX C API. The model was not modified
# Traceback (most recent call last):
#   File "/home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnxscript/version_converter/__init__.py", line 127, in call
#     converted_proto = _c_api_utils.call_onnx_api(
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnxscript/version_converter/_c_api_utils.py", line 65, in call_onnx_api
#     result = func(proto)
#              ^^^^^^^^^^^
#   File "/home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnxscript/version_converter/__init__.py", line 122, in _partial_convert_version
#     return onnx.version_converter.convert_version(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/johnario/Education/Formal/TuDelft/DSAIT 4015 - Software Engineering and Testing for AI Systems/Assignment 1/Group 2/venv/lib/python3.11/site-packages/onnx/version_converter.py", line 37, in convert_version
#     converted_model_str = C.convert_version(model_str, target_version)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: /github/workspace/onnx/version_converter/BaseConverter.h:73: adapter_lookup: Assertion `false` failed: No Adapter From Version $14 for Relu
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
#
#
# Train Accuracy of the original model: 0.8964134615384616
# Test Accuracy of the original model: 0.8955384615384615

# %% [markdown]
# ## Testing

# %%
classical_metrics = STANDARD_PERFORMANCE_METRICS
fairness_metrics = FAIRNESS_METRICS
robustness_metrics = ROBUSTNESS_METRICS

# %% [markdown]
# ### Partition Testing

# %%
partition_suite = PartitionSuite(
	problem_cols,
	classical_metrics=classical_metrics,
	test_metrics=fairness_metrics,
	verbosity=VERBOSITY
)

partition_results = partition_suite.run(models, titles, features, target)
partition_suite.save_json(partition_results, 'results/group2/results_partition.json')
# Out:
# Partition Testing Results Good Model psychological | Accuracy: 2/2 | Precision: 0/2 | Recall: 0/2 | F1 Score: 0/2 | Mean Div: 2/2 | Disp Impact: 0/2 | Calibration: 0/2 |
# Partition Testing Results Good Model medical      | Accuracy: 2/2 | Precision: 0/2 | Recall: 0/2 | F1 Score: 0/2 | Mean Div: 0/2 | Disp Impact: 0/2 | Calibration: 1/2 |
# Partition Testing Results Good Model racial       | Accuracy: 4/4 | Precision: 1/4 | Recall: 0/4 | F1 Score: 0/4 | Mean Div: 1/4 | Disp Impact: 0/4 | Calibration: 2/4 |
# Partition Testing Results Good Model subjective   | Accuracy: 3/3 | Precision: 1/3 | Recall: 0/3 | F1 Score: 0/3 | Mean Div: 1/3 | Disp Impact: 0/3 | Calibration: 1/3 |
# Partition Testing Results Good Model gender       | Accuracy: 2/2 | Precision: 1/2 | Recall: 0/2 | F1 Score: 0/2 | Mean Div: 0/2 | Disp Impact: 0/2 | Calibration: 1/2 |
# Partition Testing Results Good Model relationship | Accuracy: 3/3 | Precision: 0/3 | Recall: 0/3 | F1 Score: 0/3 | Mean Div: 1/3 | Disp Impact: 0/3 | Calibration: 0/3 |
# Partition Testing Results Good Model age          | Accuracy: 2/3 | Precision: 1/3 | Recall: 0/3 | F1 Score: 1/3 | Mean Div: 0/3 | Disp Impact: 0/3 | Calibration: 1/3 |
# Partition Testing Results Good Model irrelevant   | Accuracy: 2/2 | Precision: 0/2 | Recall: 0/2 | F1 Score: 0/2 | Mean Div: 0/2 | Disp Impact: 0/2 | Calibration: 1/2 |
# Partition Testing Results Bad Model psychological | Accuracy: 2/2 | Precision: 2/2 | Recall: 0/2 | F1 Score: 0/2 | Mean Div: 0/2 | Disp Impact: 0/2 | Calibration: 0/2 |
# Partition Testing Results Bad Model medical       | Accuracy: 2/2 | Precision: 2/2 | Recall: 0/2 | F1 Score: 0/2 | Mean Div: 0/2 | Disp Impact: 0/2 | Calibration: 0/2 |
# Partition Testing Results Bad Model racial        | Accuracy: 4/4 | Precision: 4/4 | Recall: 0/4 | F1 Score: 0/4 | Mean Div: 1/4 | Disp Impact: 0/4 | Calibration: 1/4 |
# Partition Testing Results Bad Model subjective    | Accuracy: 3/3 | Precision: 3/3 | Recall: 0/3 | F1 Score: 0/3 | Mean Div: 1/3 | Disp Impact: 0/3 | Calibration: 0/3 |
# Partition Testing Results Bad Model gender        | Accuracy: 2/2 | Precision: 2/2 | Recall: 0/2 | F1 Score: 0/2 | Mean Div: 2/2 | Disp Impact: 0/2 | Calibration: 0/2 |
# Partition Testing Results Bad Model relationship  | Accuracy: 3/3 | Precision: 3/3 | Recall: 0/3 | F1 Score: 0/3 | Mean Div: 1/3 | Disp Impact: 0/3 | Calibration: 0/3 |
# Partition Testing Results Bad Model age           | Accuracy: 3/3 | Precision: 2/3 | Recall: 1/3 | F1 Score: 1/3 | Mean Div: 0/3 | Disp Impact: 0/3 | Calibration: 0/3 |
# Partition Testing Results Bad Model irrelevant    | Accuracy: 2/2 | Precision: 2/2 | Recall: 0/2 | F1 Score: 0/2 | Mean Div: 2/2 | Disp Impact: 0/2 | Calibration: 0/2 |
# =====================================================
# = Test Target | # of Tests | Good Model | Bad Model =
# =====================================================
# Accuracy      | 21	|	20	|	21
# Precision     | 21	|	4	|	20
# Recall        | 21	|	0	|	1
# F1 Score      | 21	|	1	|	1
# Mean Div      | 21	|	5	|	7
# Disp Impact   | 21	|	0	|	0
# Calibration   | 21	|	7	|	1

# %% [markdown]
# ### Shuffle Testing

# %%
shuffle_suite = MetamorphicSuite(
	shuffle_columns,
	"Shuffle",
	tries=5,
	problem_columns=problem_cols,
	classical_metrics=classical_metrics,
	test_metrics=robustness_metrics,
	verbosity=VERBOSITY
)

shuffle_results = shuffle_suite.run(models, titles, features, target)
shuffle_suite.save_json(shuffle_results, 'results/group2/results_shuffle.json')
# Out:
# Shuffle Testing Results Good Model psychological  | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Good Model medical        | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Good Model racial         | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Good Model subjective     | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Good Model gender         | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Good Model relationship   | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Good Model age            | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Good Model irrelevant     | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Bad Model psychological   | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Bad Model medical         | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Bad Model racial          | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Bad Model subjective      | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Bad Model gender          | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Bad Model relationship    | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 0/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Bad Model age             | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Bad Model irrelevant      | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# =====================================================
# = Test Target | # of Tests | Good Model | Bad Model =
# =====================================================
# Accuracy      | 40	|	40	|	40
# Precision     | 40	|	0	|	35
# Recall        | 40	|	0	|	0
# F1 Score      | 40	|	0	|	0
# Change Rate   | 40	|	40	|	35
# Dist Shift    | 40	|	40	|	40
# Calibration   | 40	|	40	|	40

# %% [markdown]
# ### Flip Testing

# %%
flip_suite = MetamorphicSuite(
	flip_columns,
	"Flip",
	tries=1,
	problem_columns=problem_cols,
	classical_metrics=classical_metrics,
	test_metrics=robustness_metrics,
	verbosity=VERBOSITY
)

flip_results = flip_suite.run(models, titles, features, target)
flip_suite.save_json(flip_results, 'results/group2/results_flip.json')
# Out:
# Flip Testing Results Good Model psychological     | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Good Model medical           | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Good Model racial            | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Good Model subjective        | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Good Model gender            | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Good Model relationship      | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Good Model age               | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Good Model irrelevant        | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Bad Model psychological      | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Bad Model medical            | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 0/1 | Dist Shift: 1/1 | Calibration: 0/1 |
# Flip Testing Results Bad Model racial             | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 0/1 | Dist Shift: 1/1 | Calibration: 0/1 |
# Flip Testing Results Bad Model subjective         | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 0/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Bad Model gender             | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Bad Model relationship       | Accuracy: 0/1 | Precision: 0/1 | Recall: 1/1 | F1 Score: 0/1 | Change Rate: 0/1 | Dist Shift: 0/1 | Calibration: 0/1 |
# Flip Testing Results Bad Model age                | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Bad Model irrelevant         | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# =====================================================
# = Test Target | # of Tests | Good Model | Bad Model =
# =====================================================
# Accuracy      | 8	|	8	|	7
# Precision     | 8	|	0	|	7
# Recall        | 8	|	0	|	1
# F1 Score      | 8	|	0	|	0
# Change Rate   | 8	|	8	|	4
# Dist Shift    | 8	|	8	|	7
# Calibration   | 8	|	8	|	5

# %% [markdown]
# ### Noise Test

# %%
noise_suite = MetamorphicSuite(
	add_noise_to_columns,
	"Noise",
	tries=5,
	problem_columns=problem_cols,
	classical_metrics=classical_metrics,
	test_metrics=robustness_metrics,
	verbosity=VERBOSITY,
	noise_scale=2.0
)

noise_results = noise_suite.run(models, titles, features, target)
noise_suite.save_json(noise_results, 'results/group2/results_noise.json')
# Out:
# Noise Testing Results Good Model psychological    | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Good Model medical          | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Good Model racial           | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Good Model subjective       | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Good Model gender           | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Good Model relationship     | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Good Model age              | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Good Model irrelevant       | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Bad Model psychological     | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Bad Model medical           | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 0/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Bad Model racial            | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 0/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Bad Model subjective        | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Bad Model gender            | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Bad Model relationship      | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 0/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Bad Model age               | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Bad Model irrelevant        | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# =====================================================
# = Test Target | # of Tests | Good Model | Bad Model =
# =====================================================
# Accuracy      | 40	|	40	|	40
# Precision     | 40	|	0	|	25
# Recall        | 40	|	0	|	0
# F1 Score      | 40	|	0	|	0
# Change Rate   | 40	|	40	|	25
# Dist Shift    | 40	|	40	|	40
# Calibration   | 40	|	40	|	40

# %% [markdown]
# ### Scale Test

# %%
scale_suite = MetamorphicSuite(
	scale_columns,
	"Scale",
	tries=1,
	problem_columns=problem_cols,
	classical_metrics=classical_metrics,
	test_metrics=robustness_metrics,
	verbosity=VERBOSITY,
	scale_factor=1.5
)

scale_results = scale_suite.run(models, titles, features, target)
scale_suite.save_json(scale_results, 'results/group2/results_scale.json')
# Out:
# Scale Testing Results Good Model psychological    | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Good Model medical          | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Good Model racial           | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Good Model subjective       | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Good Model gender           | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Good Model relationship     | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Good Model age              | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Good Model irrelevant       | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Bad Model psychological     | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Bad Model medical           | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Bad Model racial            | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Bad Model subjective        | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Bad Model gender            | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Bad Model relationship      | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 0/1 | Dist Shift: 1/1 | Calibration: 0/1 |
# Scale Testing Results Bad Model age               | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Bad Model irrelevant        | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# =====================================================
# = Test Target | # of Tests | Good Model | Bad Model =
# =====================================================
# Accuracy      | 8	|	8	|	8
# Precision     | 8	|	0	|	7
# Recall        | 8	|	0	|	0
# F1 Score      | 8	|	0	|	0
# Change Rate   | 8	|	8	|	7
# Dist Shift    | 8	|	8	|	8
# Calibration   | 8	|	8	|	7

# %% [markdown]
# ### Shift Test

# %%
shift_suite = MetamorphicSuite(
	shift_columns,
	"Shift",
	tries=5,
	problem_columns=problem_cols,
	classical_metrics=classical_metrics,
	test_metrics=robustness_metrics,
	verbosity=VERBOSITY
)

shift_results = shift_suite.run(models, titles, features, target)
shift_suite.save_json(shift_results, 'results/group2/results_shift.json')
# Out:
# Shift Testing Results Good Model psychological    | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Good Model medical          | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Good Model racial           | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Good Model subjective       | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Good Model gender           | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Good Model relationship     | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Good Model age              | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Good Model irrelevant       | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Bad Model psychological     | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Bad Model medical           | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Bad Model racial            | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Bad Model subjective        | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Bad Model gender            | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Bad Model relationship      | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Bad Model age               | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Bad Model irrelevant        | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# =====================================================
# = Test Target | # of Tests | Good Model | Bad Model =
# =====================================================
# Accuracy      | 40	|	40	|	40
# Precision     | 40	|	0	|	35
# Recall        | 40	|	0	|	0
# F1 Score      | 40	|	0	|	0
# Change Rate   | 40	|	40	|	40
# Dist Shift    | 40	|	40	|	40
# Calibration   | 40	|	40	|	40

# %% [markdown]
# ### Quantization Test

# %%
quantization_suite = MetamorphicSuite(
	quantize_columns,
	"Quantization",
	tries=1,
	problem_columns=problem_cols,
	classical_metrics=classical_metrics,
	test_metrics=robustness_metrics,
	verbosity=VERBOSITY
)

quantization_results = quantization_suite.run(models, titles, features, target)
quantization_suite.save_json(quantization_results, 'results/group2/results_quantization.json')
# Out:
# Quantization Testing Results Good Model psychological | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Good Model medical   | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Good Model racial    | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Good Model subjective | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Good Model gender    | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Good Model relationship | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Good Model age       | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Good Model irrelevant | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Bad Model psychological | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Bad Model medical    | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 0/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Bad Model racial     | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 0/1 | Dist Shift: 1/1 | Calibration: 0/1 |
# Quantization Testing Results Bad Model subjective | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 0/1 | Dist Shift: 1/1 | Calibration: 0/1 |
# Quantization Testing Results Bad Model gender     | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Bad Model relationship | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 0/1 | Dist Shift: 1/1 | Calibration: 0/1 |
# Quantization Testing Results Bad Model age        | Accuracy: 1/1 | Precision: 0/1 | Recall: 1/1 | F1 Score: 0/1 | Change Rate: 0/1 | Dist Shift: 1/1 | Calibration: 0/1 |
# Quantization Testing Results Bad Model irrelevant | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# =====================================================
# = Test Target | # of Tests | Good Model | Bad Model =
# =====================================================
# Accuracy      | 8	|	8	|	8
# Precision     | 8	|	0	|	4
# Recall        | 8	|	0	|	1
# F1 Score      | 8	|	0	|	0
# Change Rate   | 8	|	8	|	3
# Dist Shift    | 8	|	8	|	8
# Calibration   | 8	|	8	|	4

# %% [markdown]
# ### Consistency Test

# %%
consistency_suite = ConsistencySuite(
	n_trials=10,
	sample_size=100,
	consistency_threshold=1.0,
	verbosity=VERBOSITY
)

consistency_results = consistency_suite.run(models, titles, features, target)
consistency_suite.save_json(consistency_results, 'results/group2/results_consistency.json')
# Out:
# Consistency Test Good Model:
#   Consistency Rate: 1.0000 (PASS)
#   Prediction Variance: 0.000000
#   Unanimous Predictions: 100/100
# Consistency Test Bad Model:
#   Consistency Rate: 1.0000 (PASS)
#   Prediction Variance: 0.000000
#   Unanimous Predictions: 100/100
# ========================================
# = Consistency | Good Model | Bad Model =
# ========================================
# Rate		  | 1.0000 (PASS) | 1.0000 (PASS)
# Variance	  | 0.000000 | 0.000000

# %% [markdown]
# ### Boundary Test

# %%
features_to_test = features.columns

boundary_suite = BoundarySuite(
	features_to_test=features_to_test,
	classical_metrics=classical_metrics,
	percentile_low=0.05,
	percentile_high=0.95,
	verbosity=VERBOSITY
)

boundary_results = boundary_suite.run(models, titles, features, target)
boundary_suite.save_json(boundary_results, 'results/group2/results_boundary.json')
# Out:
# Boundary Testing Good Model: 734/2520 passed
#
# Boundary Testing Bad Model: 1249/2520 passed

# %% [markdown]
# ### Monotonicity Test

# %%
monotonicity_specs = {
	'persoon_leeftijd_bij_onderzoek': 'none', # Age should not affect predictions (fairness)
	'persoon_geslacht_vrouw': 'none', # Gender should not affect predictions (fairness)
	'competentie_ethisch_en_integer_handelen': 'decreasing'
}

monotonicity_suite = MonotonicitySuite(
	monotonicity_specs=monotonicity_specs,
	violation_threshold=0.10,
	n_samples=100,
	verbosity=VERBOSITY
)

monotonicity_results = monotonicity_suite.run(models, titles, features, target)
monotonicity_suite.save_json(monotonicity_results, 'results/group2/results_monotonicity.json')
# Out:
# Monotonicity Testing Good Model: 3/3 features passed
#
# Monotonicity Testing Bad Model: 3/3 features passed
#
# =========================================
# = Monotonicity | Good Model | Bad Model =
# =========================================
# competentie_ethisch_ | 0.0000 PASS | 0.0000 PASS
# persoon_geslacht_vro | 0.0000 PASS | 0.0000 PASS
# persoon_leeftijd_bij | 0.0000 PASS | 0.0100 PASS

# %% [markdown]
# ### Group 2 Tests

# %%
model1 = SklearnModel("models/model1_1.onnx")
model2 = SklearnModel("models/model1_2.onnx")

M1_TITLE = fg.cyan + "Model A" + style.reset
M2_TITLE = fg.purple + "Model B" + style.reset

g1_models = [model1, model2]
g1_titles = [M1_TITLE, M2_TITLE]

# %%
partition_suite.run(g1_models, g1_titles, features, target)
partition_suite.save_json(partition_results, 'results/group1/results_partition.json')
# Out:
# Partition Testing Results Model A psychological    | Accuracy: 2/2 | Precision: 0/2 | Recall: 0/2 | F1 Score: 0/2 | Mean Div: 2/2 | Disp Impact: 0/2 | Calibration: 0/2 |
# Partition Testing Results Model A medical          | Accuracy: 2/2 | Precision: 0/2 | Recall: 0/2 | F1 Score: 0/2 | Mean Div: 0/2 | Disp Impact: 0/2 | Calibration: 0/2 |
# Partition Testing Results Model A racial           | Accuracy: 4/4 | Precision: 1/4 | Recall: 0/4 | F1 Score: 0/4 | Mean Div: 0/4 | Disp Impact: 0/4 | Calibration: 0/4 |
# Partition Testing Results Model A subjective       | Accuracy: 3/3 | Precision: 0/3 | Recall: 0/3 | F1 Score: 0/3 | Mean Div: 0/3 | Disp Impact: 0/3 | Calibration: 0/3 |
# Partition Testing Results Model A gender           | Accuracy: 2/2 | Precision: 0/2 | Recall: 0/2 | F1 Score: 0/2 | Mean Div: 0/2 | Disp Impact: 0/2 | Calibration: 0/2 |
# Partition Testing Results Model A relationship     | Accuracy: 3/3 | Precision: 1/3 | Recall: 0/3 | F1 Score: 0/3 | Mean Div: 1/3 | Disp Impact: 0/3 | Calibration: 0/3 |
# Partition Testing Results Model A age              | Accuracy: 2/3 | Precision: 1/3 | Recall: 0/3 | F1 Score: 0/3 | Mean Div: 0/3 | Disp Impact: 0/3 | Calibration: 0/3 |
# Partition Testing Results Model A irrelevant       | Accuracy: 2/2 | Precision: 0/2 | Recall: 0/2 | F1 Score: 0/2 | Mean Div: 2/2 | Disp Impact: 0/2 | Calibration: 0/2 |
# Partition Testing Results Model B psychological    | Accuracy: 2/2 | Precision: 2/2 | Recall: 0/2 | F1 Score: 0/2 | Mean Div: 2/2 | Disp Impact: 0/2 | Calibration: 0/2 |
# Partition Testing Results Model B medical          | Accuracy: 2/2 | Precision: 2/2 | Recall: 0/2 | F1 Score: 0/2 | Mean Div: 0/2 | Disp Impact: 0/2 | Calibration: 0/2 |
# Partition Testing Results Model B racial           | Accuracy: 4/4 | Precision: 4/4 | Recall: 0/4 | F1 Score: 0/4 | Mean Div: 1/4 | Disp Impact: 0/4 | Calibration: 1/4 |
# Partition Testing Results Model B subjective       | Accuracy: 3/3 | Precision: 3/3 | Recall: 0/3 | F1 Score: 0/3 | Mean Div: 0/3 | Disp Impact: 0/3 | Calibration: 0/3 |
# Partition Testing Results Model B gender           | Accuracy: 2/2 | Precision: 2/2 | Recall: 0/2 | F1 Score: 0/2 | Mean Div: 0/2 | Disp Impact: 0/2 | Calibration: 0/2 |
# Partition Testing Results Model B relationship     | Accuracy: 3/3 | Precision: 3/3 | Recall: 0/3 | F1 Score: 0/3 | Mean Div: 0/3 | Disp Impact: 0/3 | Calibration: 0/3 |
# Partition Testing Results Model B age              | Accuracy: 2/3 | Precision: 2/3 | Recall: 0/3 | F1 Score: 0/3 | Mean Div: 0/3 | Disp Impact: 0/3 | Calibration: 0/3 |
# Partition Testing Results Model B irrelevant       | Accuracy: 2/2 | Precision: 2/2 | Recall: 0/2 | F1 Score: 0/2 | Mean Div: 0/2 | Disp Impact: 0/2 | Calibration: 0/2 |
# ==============================================
# = Test Target | # of Tests | Model A | Model B =
# ==============================================
# Accuracy      | 21	|	20	|	20
# Precision     | 21	|	3	|	20
# Recall        | 21	|	0	|	0
# F1 Score      | 21	|	0	|	0
# Mean Div      | 21	|	5	|	3
# Disp Impact   | 21	|	0	|	0
# Calibration   | 21	|	0	|	1

# %%
shuffle_suite.run(g1_models, g1_titles, features, target)
shuffle_suite.save_json(shuffle_results, 'results/group1/results_shuffle.json')
# Out:
# Shuffle Testing Results Model A psychological      | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Model A medical            | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Model A racial             | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 0/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Model A subjective         | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Model A gender             | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Model A relationship       | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Model A age                | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Model A irrelevant         | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Model B psychological      | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Model B medical            | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Model B racial             | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Model B subjective         | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Model B gender             | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Model B relationship       | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Model B age                | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shuffle Testing Results Model B irrelevant         | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# ==============================================
# = Test Target | # of Tests | Model A | Model B =
# ==============================================
# Accuracy      | 40	|	40	|	40
# Precision     | 40	|	0	|	40
# Recall        | 40	|	0	|	0
# F1 Score      | 40	|	0	|	0
# Change Rate   | 40	|	35	|	40
# Dist Shift    | 40	|	40	|	40
# Calibration   | 40	|	40	|	40

# %%
flip_suite.run(g1_models, g1_titles, features, target)
flip_suite.save_json(flip_results, 'results/group1/results_flip.json')
# Out:
# Flip Testing Results Model A psychological         | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Model A medical               | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 0/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Model A racial                | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 0/1 | Dist Shift: 1/1 | Calibration: 0/1 |
# Flip Testing Results Model A subjective            | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 0/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Model A gender                | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Model A relationship          | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 0/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Model A age                   | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Model A irrelevant            | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Model B psychological         | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Model B medical               | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Model B racial                | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Model B subjective            | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Model B gender                | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Model B relationship          | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Model B age                   | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Flip Testing Results Model B irrelevant            | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# ==============================================
# = Test Target | # of Tests | Model A | Model B =
# ==============================================
# Accuracy      | 8	|	8	|	8
# Precision     | 8	|	0	|	8
# Recall        | 8	|	0	|	0
# F1 Score      | 8	|	0	|	0
# Change Rate   | 8	|	4	|	8
# Dist Shift    | 8	|	8	|	8
# Calibration   | 8	|	7	|	8

# %%
noise_suite.run(g1_models, g1_titles, features, target)
noise_suite.save_json(noise_results, 'results/group1/results_noise.json')
# Out:
# Noise Testing Results Model A psychological        | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Model A medical              | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Model A racial               | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 0/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Model A subjective           | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Model A gender               | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Model A relationship         | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Model A age                  | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Model A irrelevant           | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Model B psychological        | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Model B medical              | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Model B racial               | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Model B subjective           | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Model B gender               | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Model B relationship         | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Model B age                  | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Noise Testing Results Model B irrelevant           | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# ==============================================
# = Test Target | # of Tests | Model A | Model B =
# ==============================================
# Accuracy      | 40	|	40	|	40
# Precision     | 40	|	0	|	40
# Recall        | 40	|	0	|	0
# F1 Score      | 40	|	0	|	0
# Change Rate   | 40	|	35	|	40
# Dist Shift    | 40	|	40	|	40
# Calibration   | 40	|	40	|	40

# %%
scale_results = scale_suite.run(g1_models, g1_titles, features, target)
scale_suite.save_json(scale_results, 'results/group1/results_scale.json')
# Out:
# Scale Testing Results Model A psychological        | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Model A medical              | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Model A racial               | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Model A subjective           | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Model A gender               | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Model A relationship         | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Model A age                  | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Model A irrelevant           | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Model B psychological        | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Model B medical              | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Model B racial               | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Model B subjective           | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Model B gender               | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Model B relationship         | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Model B age                  | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Scale Testing Results Model B irrelevant           | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# ==============================================
# = Test Target | # of Tests | Model A | Model B =
# ==============================================
# Accuracy      | 8	|	8	|	8
# Precision     | 8	|	0	|	8
# Recall        | 8	|	0	|	0
# F1 Score      | 8	|	0	|	0
# Change Rate   | 8	|	8	|	8
# Dist Shift    | 8	|	8	|	8
# Calibration   | 8	|	8	|	8

# %%
shift_results = shift_suite.run(g1_models, g1_titles, features, target)
shift_suite.save_json(shift_results, 'results/group1/results_shift.json')
# Out:
# Shift Testing Results Model A psychological        | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Model A medical              | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Model A racial               | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Model A subjective           | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Model A gender               | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Model A relationship         | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Model A age                  | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Model A irrelevant           | Accuracy: 5/5 | Precision: 0/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Model B psychological        | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Model B medical              | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Model B racial               | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Model B subjective           | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Model B gender               | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Model B relationship         | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Model B age                  | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# Shift Testing Results Model B irrelevant           | Accuracy: 5/5 | Precision: 5/5 | Recall: 0/5 | F1 Score: 0/5 | Change Rate: 5/5 | Dist Shift: 5/5 | Calibration: 5/5 |
# ==============================================
# = Test Target | # of Tests | Model A | Model B =
# ==============================================
# Accuracy      | 40	|	40	|	40
# Precision     | 40	|	0	|	40
# Recall        | 40	|	0	|	0
# F1 Score      | 40	|	0	|	0
# Change Rate   | 40	|	40	|	40
# Dist Shift    | 40	|	40	|	40
# Calibration   | 40	|	40	|	40

# %%
quantization_results = quantization_suite.run(g1_models, g1_titles, features, target)
quantization_suite.save_json(quantization_results, 'results/group1/results_quantization.json')
# Out:
# Quantization Testing Results Model A psychological | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Model A medical       | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Model A racial        | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 0/1 | Dist Shift: 1/1 | Calibration: 0/1 |
# Quantization Testing Results Model A subjective    | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Model A gender        | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Model A relationship  | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Model A age           | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Model A irrelevant    | Accuracy: 1/1 | Precision: 0/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Model B psychological | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Model B medical       | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Model B racial        | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Model B subjective    | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Model B gender        | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Model B relationship  | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Model B age           | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# Quantization Testing Results Model B irrelevant    | Accuracy: 1/1 | Precision: 1/1 | Recall: 0/1 | F1 Score: 0/1 | Change Rate: 1/1 | Dist Shift: 1/1 | Calibration: 1/1 |
# ==============================================
# = Test Target | # of Tests | Model A | Model B =
# ==============================================
# Accuracy      | 8	|	8	|	8
# Precision     | 8	|	0	|	8
# Recall        | 8	|	0	|	0
# F1 Score      | 8	|	0	|	0
# Change Rate   | 8	|	7	|	8
# Dist Shift    | 8	|	8	|	8
# Calibration   | 8	|	7	|	8

# %%
consistency_suite.run(g1_models, g1_titles, features, target)
consistency_suite.save_json(consistency_results, 'results/group1/results_consistency.json')
# Out:
# Consistency Test Model A:
#   Consistency Rate: 1.0000 (PASS)
#   Prediction Variance: 0.000000
#   Unanimous Predictions: 100/100
# Consistency Test Model B:
#   Consistency Rate: 1.0000 (PASS)
#   Prediction Variance: 0.000000
#   Unanimous Predictions: 100/100
# =================================
# = Consistency | Model A | Model B =
# =================================
# Rate		  | 1.0000 (PASS) | 1.0000 (PASS)
# Variance	  | 0.000000 | 0.000000

# %%
boundary_suite.run(g1_models, g1_titles, features, target)
boundary_suite.save_json(boundary_results, 'results/group1/results_boundary.json')
# Out:
# Boundary Testing Model A: 626/2520 passed
#
# Boundary Testing Model B: 1242/2520 passed

# %%
monotonicity_suite.run(g1_models, g1_titles, features, target)
monotonicity_suite.save_json(monotonicity_results, 'results/group1/results_monotonicity.json')
# Out:
# Monotonicity Testing Model A: 3/3 features passed
#
# Monotonicity Testing Model B: 3/3 features passed
#
# ==================================
# = Monotonicity | Model A | Model B =
# ==================================
# competentie_ethisch_ | 0.0000 PASS | 0.0000 PASS
# persoon_geslacht_vro | 0.0000 PASS | 0.0000 PASS
# persoon_leeftijd_bij | 0.0100 PASS | 0.0000 PASS
