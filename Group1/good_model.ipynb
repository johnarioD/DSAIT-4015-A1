# %%
import re
import pandas as pd
import numpy as np
import onnx
import onnxruntime as rt
from skl2onnx import to_onnx, convert_sklearn
from skl2onnx.common.data_types import FloatTensorType
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, TargetEncoder, OrdinalEncoder, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import DecisionTreeClassifier
# from plotting import plotCorrelation, plotColumnBarchartGrid
from sklearn.ensemble import HistGradientBoostingClassifier
# Out:
# /tmp/ipykernel_3789/2642258525.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv('data/synth_data_for_training.csv')
target_col = 'checked' 
y = data[target_col]
X = data.drop([target_col], axis=1)
# print(X.dtypes.unique())
X = X.astype(np.float32)
# print(f"Shape of X: {X.shape}")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# print(f"Training dataset shape: {X_train.shape}")

# print()
correlations = X.corrwith(y)
corr_df = pd.DataFrame({
    'correlation': correlations,
    'abs_correlation': correlations.abs()
})
sorted_corr = corr_df.sort_values(by='abs_correlation', ascending=False)
unique_vals = X["contacten_onderwerp__werk_intake"].nunique
print(unique_vals)
# print(sorted_corr[['correlation']].head(50))
# Out:
# <bound method IndexOpsMixin.nunique of 0        2.0
# 1        1.0
# 2        1.0
# 3        0.0
# 4        2.0
#         ...
# 12640    0.0
# 12641    1.0
# 12642    0.0
# 12643    0.0
# 12644    1.0
# Name: contacten_onderwerp__werk_intake, Length: 12645, dtype: float32>
# /home/SinJ/miniconda3/envs/dsait4015/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/SinJ/miniconda3/envs/dsait4015/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
print("\nData Statistics (Min, Max, Mean, Variance):")
stats = X.agg(['min', 'max', 'mean', 'var']).transpose()
print(stats.to_string(float_format="%.4f"))
# Out:
# Data Statistics (Min, Max, Mean, Variance):
#                                                                                                        min        max      mean           var
# adres_aantal_brp_adres                                                                              1.0000    11.0000    2.8785        2.1243
# adres_aantal_verschillende_wijken                                                                   1.0000     7.0000    2.1016        0.8740
# adres_aantal_verzendadres                                                                           0.0000     3.0000    0.4333        0.2737
# adres_aantal_woonadres_handmatig                                                                    0.0000     3.0000    0.4943        0.3109
# adres_dagen_op_adres                                                                                3.0000 24326.0000 9904.9463 40152840.0000
# adres_recentst_onderdeel_rdam                                                                       0.0000     1.0000    0.9504        0.0471
# adres_recentste_buurt_groot_ijsselmonde                                                             0.0000     1.0000    0.0036        0.0036
# adres_recentste_buurt_nieuwe_westen                                                                 0.0000     1.0000    0.0023        0.0023
# adres_recentste_buurt_other                                                                         0.0000     1.0000    0.4996        0.2500
# adres_recentste_buurt_oude_noorden                                                                  0.0000     1.0000    0.0009        0.0009
# adres_recentste_buurt_vreewijk                                                                      0.0000     1.0000    0.0047        0.0047
# adres_recentste_plaats_other                                                                        0.0000     1.0000    0.0067        0.0067
# adres_recentste_plaats_rotterdam                                                                    0.0000     1.0000    0.9117        0.0805
# adres_recentste_wijk_charlois                                                                       0.0000     1.0000    0.1023        0.0919
# adres_recentste_wijk_delfshaven                                                                     0.0000     1.0000    0.1336        0.1158
# adres_recentste_wijk_feijenoord                                                                     0.0000     1.0000    0.1707        0.1416
# adres_recentste_wijk_ijsselmonde                                                                    0.0000     1.0000    0.0433        0.0414
# adres_recentste_wijk_kralingen_c                                                                    0.0000     1.0000    0.0482        0.0459
# adres_recentste_wijk_noord                                                                          0.0000     1.0000    0.0219        0.0214
# adres_recentste_wijk_other                                                                          0.0000     1.0000    0.1332        0.1154
# adres_recentste_wijk_prins_alexa                                                                    0.0000     1.0000    0.0396        0.0381
# adres_recentste_wijk_stadscentru                                                                    0.0000     1.0000    0.0123        0.0122
# adres_unieke_wijk_ratio                                                                             0.0000     1.0000    0.8952        0.0938
# afspraak_aanmelding_afgesloten                                                                      0.0000     9.0000    1.8550        1.7499
# afspraak_aantal_woorden                                                                             0.0000  1066.0000  255.9184    24669.2168
# afspraak_afgelopen_jaar_afsprakenplan                                                               0.0000     3.0000    0.4452        0.2791
# afspraak_afgelopen_jaar_monitoring_insp__wet_taaleis_na_12_mnd_n_a_v__taa04_____geen_maatregel      0.0000     1.0000    0.0240        0.0235
# afspraak_afgelopen_jaar_ontheffing                                                                  0.0000     2.0000    0.4377        0.2558
# afspraak_afgelopen_jaar_ontheffing_taaleis                                                          0.0000     1.0000    0.0853        0.0781
# afspraak_afgelopen_jaar_plan_van_aanpak                                                             0.0000     4.0000    0.8433        0.5898
# afspraak_afgelopen_jaar_signaal_voor_medewerker                                                     0.0000     9.0000    1.8379        2.0822
# afspraak_afgelopen_jaar_vervolgmeting_matchbaarheid_werkzoekende_klant                              0.0000     1.0000    0.1543        0.1305
# afspraak_afgelopen_jaar_voortgang_aanmelding_en_deelname                                            0.0000     9.0000    1.7934        2.1687
# afspraak_afsprakenplan                                                                              0.0000     6.0000    1.3062        0.9621
# afspraak_controle_aankondiging_maatregel                                                            0.0000     2.0000    0.4161        0.2621
# afspraak_controle_verwijzing                                                                        0.0000     2.0000    0.2490        0.1872
# afspraak_deelname_compleet_uit_webapplicatie                                                        0.0000     4.0000    0.9942        0.5965
# afspraak_galo_gesprek                                                                               0.0000     3.0000    0.5142        0.3136
# afspraak_gespr__einde_zoekt___galo_gesprek_                                                         0.0000     2.0000    0.3162        0.2207
# afspraak_inspanningsperiode                                                                         0.0000     3.0000    0.5816        0.3482
# afspraak_laatstejaar_aantal_woorden                                                                 0.0000   411.0000   86.5849     4472.9668
# afspraak_laatstejaar_resultaat_ingevuld                                                             0.0000     8.0000    1.8198        2.2243
# afspraak_laatstejaar_resultaat_ingevuld_uniek                                                       0.0000     6.0000    1.4431        1.0193
# afspraak_other                                                                                      0.0000     6.0000    1.2813        0.9652
# afspraak_participatietrede_vervolgmeting                                                            0.0000     4.0000    1.0140        0.6122
# afspraak_resultaat_ingevuld_uniek                                                                   0.0000     9.0000    3.0457        2.0084
# afspraak_signaal_van_aanbieder                                                                      0.0000     7.0000    1.4647        1.1749
# afspraak_signaal_voor_medewerker                                                                    0.0000    19.0000    4.1366        8.1834
# afspraak_toevoegen_inschrijving_uwvwb                                                               0.0000     2.0000    0.3860        0.2536
# afspraak_vervolgmeting_matchbaarheid_werkzoekende_klant                                             0.0000     2.0000    0.3802        0.2448
# afspraak_verzenden_beschikking_i_v_m__niet_voldoen_aan_wet_taaleis                                  0.0000     1.0000    0.1639        0.1370
# afspraak_voortgangsgesprek                                                                          0.0000     5.0000    0.9878        0.6498
# belemmering_aantal_huidig                                                                           0.0000     7.0000    1.5964        1.4282
# belemmering_dagen_financiele_problemen                                                         -11479.0000 11918.0000  405.1853  9090617.0000
# belemmering_dagen_lichamelijke_problematiek                                                    -15300.0000 27183.0000 1357.1970 44194308.0000
# belemmering_dagen_psychische_problemen                                                         -52171.0000 16886.0000 1494.0472 90682024.0000
# belemmering_financiele_problemen                                                                    0.0000     1.0000    0.3128        0.2150
# belemmering_hist_lichamelijke_problematiek                                                          0.0000     3.0000    0.5333        0.3093
# belemmering_hist_psychische_problemen                                                               0.0000     3.0000    0.5219        0.2978
# belemmering_hist_stabiele_mix__sz____dagbesteding_werk                                              0.0000     1.0000    0.0739        0.0684
# belemmering_hist_taal                                                                               0.0000     1.0000    0.0709        0.0659
# belemmering_hist_verslavingsproblematiek                                                            0.0000     1.0000    0.0595        0.0559
# belemmering_ind                                                                                     0.0000     1.0000    0.6036        0.2393
# belemmering_ind_hist                                                                                0.0000     1.0000    0.6312        0.2328
# belemmering_niet_computervaardig                                                                    0.0000     1.0000    0.0098        0.0097
# belemmering_psychische_problemen                                                                    0.0000     1.0000    0.4845        0.2498
# belemmering_woonsituatie                                                                            0.0000     1.0000    0.0063        0.0063
# beschikbaarheid_aantal_historie_afwijkend_wegens_medische_omstandigheden                            0.0000     4.0000    1.0003        0.4549
# beschikbaarheid_aantal_historie_afwijkend_wegens_sociaal_maatschappelijke_situatie                  0.0000     2.0000    0.4406        0.2614
# beschikbaarheid_huidig_afwijkend_wegens_medische_omstandigheden                                     0.0000     1.0000    0.0367        0.0354
# beschikbaarheid_huidig_bekend                                                                       0.0000     1.0000    0.2172        0.1701
# beschikbaarheid_recent_afwijkend_wegens_medische_omstandigheden                                     0.0000     1.0000    0.5086        0.2499
# beschikbaarheid_recent_afwijkend_wegens_sociaal_maatschappelijke_situatie                           0.0000     1.0000    0.1120        0.0994
# competentie_aansturen                                                                               0.0000     2.0000    0.2989        0.2135
# competentie_analyseren                                                                              0.0000     2.0000    0.2985        0.2111
# competentie_ethisch_en_integer_handelen                                                             0.0000     1.0000    0.1480        0.1261
# competentie_formuleren_en_rapporteren                                                               0.0000     2.0000    0.2690        0.1983
# competentie_gedrevenheid_en_ambitie_tonen                                                           0.0000     2.0000    0.1684        0.1402
# competentie_instructies_en_procedures_opvolgen                                                      0.0000     2.0000    0.3839        0.2500
# competentie_kwaliteit_leveren                                                                       0.0000     3.0000    0.3902        0.2568
# competentie_leren                                                                                   0.0000     1.0000    0.1542        0.1304
# competentie_materialen_en_middelen_inzetten                                                         0.0000     2.0000    0.2923        0.2100
# competentie_met_druk_en_tegenslag_omgaan                                                            0.0000     2.0000    0.2347        0.1800
# competentie_omgaan_met_verandering_en_aanpassen                                                     0.0000     2.0000    0.2220        0.1732
# competentie_onderzoeken                                                                             0.0000     1.0000    0.1538        0.1302
# competentie_op_de_behoeften_en_verwachtingen_van_de__klant__richten                                 0.0000     1.0000    0.1644        0.1374
# competentie_other                                                                                   0.0000     7.0000    1.5195        1.3754
# competentie_overtuigen_en_beïnvloeden                                                               0.0000     2.0000    0.3036        0.2151
# competentie_plannen_en_organiseren                                                                  0.0000     2.0000    0.3313        0.2271
# competentie_samenwerken_en_overleggen                                                               0.0000     3.0000    0.3834        0.2502
# competentie_vakdeskundigheid_toepassen                                                              0.0000     3.0000    0.4742        0.2913
# contacten_onderwerp__arbeids_motivatie                                                              0.0000    17.0000    3.5865        6.3044
# contacten_onderwerp__pre__intake                                                                    0.0000     3.0000    0.5242        0.3149
# contacten_onderwerp__werk_intake                                                                    0.0000     4.0000    0.6245        0.3864
# contacten_onderwerp_arbeidsdiagnose_dariuz                                                          0.0000     2.0000    0.3253        0.2258
# contacten_onderwerp_beoordelen_taaleis                                                              0.0000     4.0000    0.8247        0.5059
# contacten_onderwerp_boolean__arbeids_motivatie                                                      0.0000     1.0000    0.6093        0.2381
# contacten_onderwerp_boolean__pre__intake                                                            0.0000     1.0000    0.3268        0.2200
# contacten_onderwerp_boolean__werk_intake                                                            0.0000     1.0000    0.3261        0.2198
# contacten_onderwerp_boolean_beoordelen_taaleis                                                      0.0000     1.0000    0.2904        0.2061
# contacten_onderwerp_boolean_contact_derden                                                          0.0000     1.0000    0.4950        0.2500
# contacten_onderwerp_boolean_contact_met_aanbieder                                                   0.0000     1.0000    0.4896        0.2499
# contacten_onderwerp_boolean_diagnosegesprek                                                         0.0000     1.0000    0.2432        0.1841
# contacten_onderwerp_boolean_documenten__innemen_                                                    0.0000     1.0000    0.7439        0.1906
# contacten_onderwerp_boolean_documenttype__cv_                                                       0.0000     1.0000    0.3672        0.2324
# contacten_onderwerp_boolean_documenttype__diploma_s_en_certificaten_                                0.0000     1.0000    0.2064        0.1638
# contacten_onderwerp_boolean_documenttype__overeenkomst_                                             0.0000     1.0000    0.4670        0.2489
# contacten_onderwerp_boolean_financiële_situatie                                                     0.0000     1.0000    0.1951        0.1570
# contacten_onderwerp_boolean_groepsbijeenkomst                                                       0.0000     1.0000    0.4275        0.2448
# contacten_onderwerp_boolean_inkomen                                                                 0.0000     1.0000    0.2901        0.2059
# contacten_onderwerp_boolean_maatregel_overweging                                                    0.0000     1.0000    0.2282        0.1762
# contacten_onderwerp_boolean_match___werk                                                            0.0000     1.0000    0.0497        0.0473
# contacten_onderwerp_boolean_matching                                                                0.0000     1.0000    0.1952        0.1571
# contacten_onderwerp_boolean_motivatie                                                               0.0000     1.0000    0.0099        0.0098
# contacten_onderwerp_boolean_mutatie                                                                 0.0000     1.0000    0.0231        0.0226
# contacten_onderwerp_boolean_no_show                                                                 0.0000     1.0000    0.4512        0.2476
# contacten_onderwerp_boolean_overige                                                                 0.0000     1.0000    0.7033        0.2087
# contacten_onderwerp_boolean_overleg_met_inkomen                                                     0.0000     1.0000    0.3681        0.2326
# contacten_onderwerp_boolean_scholing                                                                0.0000     1.0000    0.1361        0.1176
# contacten_onderwerp_boolean_sollicitatie                                                            0.0000     1.0000    0.0380        0.0365
# contacten_onderwerp_boolean_taaleis___voldoet                                                       0.0000     1.0000    0.2750        0.1994
# contacten_onderwerp_boolean_terugbelverzoek                                                         0.0000     1.0000    0.6134        0.2371
# contacten_onderwerp_boolean_traject                                                                 0.0000     1.0000    0.7274        0.1983
# contacten_onderwerp_boolean_uitnodiging                                                             0.0000     1.0000    0.4594        0.2484
# contacten_onderwerp_boolean_ziek__of_afmelding                                                      0.0000     1.0000    0.4891        0.2499
# contacten_onderwerp_boolean_zorg                                                                    0.0000     1.0000    0.5872        0.2424
# contacten_onderwerp_contact_derden                                                                  0.0000    13.0000    2.6921        3.7122
# contacten_onderwerp_contact_met_aanbieder                                                           0.0000    13.0000    2.7854        3.9465
# contacten_onderwerp_diagnosegesprek                                                                 0.0000     3.0000    0.4861        0.2971
# contacten_onderwerp_documenten__innemen_                                                            0.0000    17.0000    3.7967        7.5495
# contacten_onderwerp_documenttype__cv_                                                               0.0000     5.0000    0.9907        0.6757
# contacten_onderwerp_documenttype__overeenkomst_                                                     0.0000     7.0000    1.2827        1.0157
# contacten_onderwerp_financiële_situatie                                                             0.0000    10.0000    1.8410        2.0315
# contacten_onderwerp_groepsbijeenkomst                                                               0.0000     5.0000    0.8930        0.6041
# contacten_onderwerp_inkomen                                                                         0.0000     5.0000    0.9250        0.6322
# contacten_onderwerp_inname_aanvraag                                                                 0.0000     1.0000    0.1943        0.1566
# contacten_onderwerp_inspanningstoets                                                                0.0000     3.0000    0.4929        0.3025
# contacten_onderwerp_maatregel_overweging                                                            0.0000     3.0000    0.5868        0.3512
# contacten_onderwerp_matching                                                                        0.0000    20.0000    3.3510        6.0687
# contacten_onderwerp_mutatie                                                                         0.0000     2.0000    0.2624        0.1950
# contacten_onderwerp_no_show                                                                         0.0000     6.0000    1.1038        0.8112
# contacten_onderwerp_overige                                                                         0.0000    30.0000    7.3708       25.4518
# contacten_onderwerp_overleg_met_inkomen                                                             0.0000     6.0000    1.0319        0.7278
# contacten_onderwerp_quickscan                                                                       0.0000     2.0000    0.2244        0.1744
# contacten_onderwerp_scholing                                                                        0.0000     4.0000    0.8353        0.5115
# contacten_onderwerp_screening                                                                       0.0000     2.0000    0.4651        0.2774
# contacten_onderwerp_terugbelverzoek                                                                 0.0000    19.0000    3.9357        7.6459
# contacten_onderwerp_traject                                                                         0.0000    31.0000    6.7319       21.0681
# contacten_onderwerp_uitnodiging                                                                     0.0000     8.0000    1.4265        1.2369
# contacten_onderwerp_vakantie                                                                        0.0000     1.0000    0.1199        0.1055
# contacten_onderwerp_werkintake__niet_verschenen                                                     0.0000     2.0000    0.2153        0.1693
# contacten_onderwerp_ziek__of_afmelding                                                              0.0000     8.0000    1.6422        1.4890
# contacten_onderwerp_zorg                                                                            0.0000    12.0000    2.8178        3.8969
# contacten_soort_afgelopenjaar_anders                                                                0.0000     6.0000    1.1122        0.8644
# contacten_soort_afgelopenjaar_document__inkomend_                                                   0.0000     9.0000    1.5299        1.6272
# contacten_soort_afgelopenjaar_document__uitgaand_                                                   0.0000    26.0000    3.6770        8.4689
# contacten_soort_afgelopenjaar_e_mail__inkomend_                                                     0.0000     8.0000    1.6437        1.7036
# contacten_soort_afgelopenjaar_e_mail__uitgaand_                                                     0.0000    10.0000    1.7091        1.9002
# contacten_soort_afgelopenjaar_gesprek                                                               0.0000     7.0000    1.3240        1.2268
# contacten_soort_afgelopenjaar_gesprek_op_locatie                                                    0.0000     1.0000    0.1117        0.0993
# contacten_soort_afgelopenjaar_rapportage_rib                                                        0.0000     4.0000    0.7947        0.4980
# contacten_soort_afgelopenjaar_telefoontje__inkomend_                                                0.0000     7.0000    1.3238        1.1924
# contacten_soort_afgelopenjaar_telefoontje__uitgaand_                                                0.0000     7.0000    1.3968        1.2740
# contacten_soort_anders                                                                              0.0000    16.0000    3.0997        4.9341
# contacten_soort_document__inkomend_                                                                 0.0000    37.0000    8.5318       33.0742
# contacten_soort_document__uitgaand_                                                                 0.0000    95.0000   25.6176      231.2231
# contacten_soort_e_mail__inkomend_                                                                   0.0000    33.0000    6.7155       21.4826
# contacten_soort_e_mail__uitgaand_                                                                   0.0000    25.0000    5.5662       15.2504
# contacten_soort_gesprek_op_locatie                                                                  0.0000     2.0000    0.2615        0.1944
# contacten_soort_groepsbijeenkomsten                                                                 0.0000     2.0000    0.3312        0.2291
# contacten_soort_rapportage_deelname                                                                 0.0000     8.0000    1.6020        1.4566
# contacten_soort_rapportage_rib                                                                      0.0000     7.0000    1.6238        1.4152
# contacten_soort_telefoontje__inkomend_                                                              0.0000    22.0000    4.9328       11.4069
# contacten_soort_telefoontje__uitgaand_                                                              0.0000    21.0000    4.3295        9.0240
# deelname_act_actueel_projecten_uniek                                                                0.0000     4.0000    0.6842        0.4383
# deelname_act_hist_projecten_niet_gestart                                                            0.0000     8.0000    1.7155        1.6096
# deelname_act_reintegratieladder_ondersteunende_instrumenten                                         0.0000    14.0000    3.2393        4.7931
# deelname_act_reintegratieladder_werk_re_integratie                                                  0.0000    19.0000    4.1321        8.3697
# instrument_aantal_laatstejaar                                                                       0.0000     5.0000    0.9970        0.7989
# instrument_ladder_historie_activering                                                               0.0000    11.0000    2.3193        2.9377
# instrument_ladder_historie_other                                                                    0.0000     3.0000    0.6393        0.3954
# instrument_ladder_huidig_activering                                                                 0.0000     3.0000    0.5874        0.3616
# instrument_ladder_huidig_other                                                                      0.0000     2.0000    0.3440        0.2320
# instrument_ladder_huidig_werk_re_integratie                                                         0.0000     2.0000    0.3836        0.2512
# instrument_reden_beeindiging_historie_centrale_actie_wigo4it                                        0.0000     4.0000    0.6482        0.3867
# instrument_reden_beeindiging_historie_diagnose_gesteld                                              0.0000     1.0000    0.0937        0.0849
# instrument_reden_beeindiging_historie_direct_matchbaar                                              0.0000     1.0000    0.0243        0.0237
# instrument_reden_beeindiging_historie_doelstelling_bereikt__geen_uitstroom                          0.0000     6.0000    1.3911        1.0495
# instrument_reden_beeindiging_historie_doelstelling_bereikt__uitstroom_naar_regulier_werk            0.0000     1.0000    0.0693        0.0645
# instrument_reden_beeindiging_historie_doelstelling_bereikt__uitstroom_overig                        0.0000     1.0000    0.1151        0.1019
# instrument_reden_beeindiging_historie_doelstelling_niet_bereikt__geen_uitstroom                     0.0000     6.0000    1.2203        0.9195
# instrument_reden_beeindiging_historie_niet_matchbaar                                                0.0000     1.0000    0.1144        0.1013
# instrument_reden_beeindiging_historie_niet_succesvol                                                0.0000     4.0000    0.8389        0.5070
# instrument_reden_beeindiging_historie_niet_succesvol__reden_bij_werkzoekende                        0.0000     1.0000    0.0431        0.0412
# instrument_reden_beeindiging_historie_op_termijn_matchbaar                                          0.0000     1.0000    0.1692        0.1406
# instrument_reden_beeindiging_historie_other                                                         0.0000     4.0000    0.6695        0.3893
# instrument_reden_beeindiging_historie_overdracht_naar_mo                                            0.0000     2.0000    0.2206        0.1724
# instrument_reden_beeindiging_historie_overdracht_naar_prematching                                   0.0000     1.0000    0.0898        0.0817
# instrument_reden_beeindiging_historie_overdracht_naar_regulier_team_iwpm                            0.0000     1.0000    0.0219        0.0214
# instrument_reden_beeindiging_historie_overdracht_succesvol                                          0.0000     2.0000    0.2792        0.2036
# instrument_reden_beeindiging_historie_succesvol                                                     0.0000     7.0000    1.4471        1.1593
# instrument_reden_beeindiging_historie_succesvol__doelstelling_bereikt                               0.0000     1.0000    0.0393        0.0378
# instrument_reden_beeindiging_historie_uitval__aanbod_niet_langer_zinvol_volgens_gemeente            0.0000     3.0000    0.5423        0.3200
# instrument_reden_beeindiging_historie_uitval__klant_wz__ziet_af_van_aanbod                          0.0000     2.0000    0.2097        0.1661
# ontheffing_actueel_ind                                                                              0.0000     1.0000    0.2991        0.2097
# ontheffing_dagen_hist_mean                                                                        120.0000  4710.0000 1599.2222   493356.0312
# ontheffing_dagen_hist_vanwege_uw_medische_omstandigheden                                            3.0000  7526.0000 1858.5948  1373192.3750
# ontheffing_hist_ind                                                                                 1.0000     1.0000    1.0000        0.0000
# ontheffing_reden_hist_medische_gronden                                                              0.0000     2.0000    0.5171        0.2785
# ontheffing_reden_hist_other                                                                         0.0000     1.0000    0.0196        0.0192
# ontheffing_reden_hist_sociale_gronden                                                               0.0000     1.0000    0.1802        0.1478
# ontheffing_reden_hist_tijdelijke_ontheffing_arbeidsverpl__en_tegenprestatie                         0.0000     2.0000    0.2997        0.2104
# ontheffing_reden_hist_tijdelijke_ontheffing_arbeidsverplichtingen                                   0.0000     1.0000    0.0384        0.0370
# ontheffing_reden_hist_vanwege_uw_sociaal_maatschappelijke_situatie                                  0.0000     2.0000    0.2514        0.1888
# ontheffing_reden_tijdelijke_ontheffing_arbeidsverpl__en_tegenprestatie                              0.0000     1.0000    0.0855        0.0782
# persoon_geslacht_vrouw                                                                              0.0000     1.0000    0.4826        0.2497
# persoon_leeftijd_bij_onderzoek                                                                     19.0000    67.0000   49.2932       99.8042
# persoonlijke_eigenschappen_communicatie_opm                                                         0.0000     1.0000    0.5253        0.2494
# persoonlijke_eigenschappen_dagen_sinds_opvoer                                                       0.0000  2373.0000  465.5755   124839.3047
# persoonlijke_eigenschappen_dagen_sinds_taaleis                                                      0.0000  1755.0000  437.8538    94403.0312
# persoonlijke_eigenschappen_doorzettingsvermogen_opm                                                 0.0000     1.0000    0.4651        0.2488
# persoonlijke_eigenschappen_flexibiliteit_opm                                                        0.0000     1.0000    0.5047        0.2500
# persoonlijke_eigenschappen_hobbies_sport                                                            0.0000     1.0000    0.3955        0.2391
# persoonlijke_eigenschappen_houding_opm                                                              0.0000     1.0000    0.5193        0.2496
# persoonlijke_eigenschappen_ind_activering_traject                                                   0.0000     1.0000    0.1449        0.1239
# persoonlijke_eigenschappen_ind_buiten_kantoortijden                                                 0.0000     1.0000    0.1539        0.1302
# persoonlijke_eigenschappen_ind_regulier_arbeidsritme                                                0.0000     1.0000    0.2622        0.1935
# persoonlijke_eigenschappen_initiatief_opm                                                           0.0000     1.0000    0.4643        0.2487
# persoonlijke_eigenschappen_leergierigheid_opm                                                       0.0000     1.0000    0.4800        0.2496
# persoonlijke_eigenschappen_motivatie_opm                                                            0.0000     1.0000    0.5790        0.2438
# persoonlijke_eigenschappen_nl_begrijpen3                                                            0.0000     1.0000    0.0372        0.0359
# persoonlijke_eigenschappen_nl_lezen3                                                                0.0000     1.0000    0.0579        0.0545
# persoonlijke_eigenschappen_nl_lezen4                                                                0.0000     1.0000    0.0161        0.0158
# persoonlijke_eigenschappen_nl_schrijven0                                                            0.0000     1.0000    0.3216        0.2182
# persoonlijke_eigenschappen_nl_schrijven1                                                            0.0000     1.0000    0.0963        0.0871
# persoonlijke_eigenschappen_nl_schrijven2                                                            0.0000     1.0000    0.3457        0.2262
# persoonlijke_eigenschappen_nl_schrijven3                                                            0.0000     1.0000    0.0511        0.0485
# persoonlijke_eigenschappen_nl_schrijvenfalse                                                        0.0000     1.0000    0.0038        0.0038
# persoonlijke_eigenschappen_nl_spreken1                                                              0.0000     1.0000    0.1820        0.1489
# persoonlijke_eigenschappen_nl_spreken2                                                              0.0000     1.0000    0.4077        0.2415
# persoonlijke_eigenschappen_nl_spreken3                                                              0.0000     1.0000    0.0282        0.0274
# persoonlijke_eigenschappen_opstelling                                                               0.0000     1.0000    0.5723        0.2448
# persoonlijke_eigenschappen_overige_opmerkingen                                                      0.0000     1.0000    0.2244        0.1741
# persoonlijke_eigenschappen_presentatie_opm                                                          0.0000     1.0000    0.4673        0.2490
# persoonlijke_eigenschappen_spreektaal                                                               0.0000    99.0000   32.2663      922.5276
# persoonlijke_eigenschappen_spreektaal_anders                                                        0.0000     1.0000    0.4750        0.2494
# persoonlijke_eigenschappen_taaleis_schrijfv_ok                                                      0.0000     1.0000    0.4491        0.2474
# persoonlijke_eigenschappen_taaleis_voldaan                                                          0.0000     2.0000    0.6479        0.3216
# persoonlijke_eigenschappen_uiterlijke_verzorging_opm                                                0.0000     1.0000    0.4643        0.2487
# persoonlijke_eigenschappen_uitstroom_verw_vlgs_klant                                                0.0000     6.0000    2.0871        7.2600
# persoonlijke_eigenschappen_uitstroom_verw_vlgs_km                                                   0.0000     6.0000    2.3322        7.8622
# persoonlijke_eigenschappen_zelfstandigheid_opm                                                      0.0000     1.0000    0.4683        0.2490
# pla_actueel_pla_categorie_doelstelling_16                                                           0.0000     2.0000    0.3443        0.2331
# pla_actueel_pla_categorie_doelstelling_9                                                            0.0000     1.0000    0.2115        0.1668
# pla_einde_doelstelling_bereikt                                                                      0.0000     3.0000    0.6691        0.3997
# pla_einde_doelstelling_bereikt__nieuw_trajectplan                                                   0.0000     4.0000    1.1133        0.7533
# pla_einde_doelstelling_bereikt__overdracht                                                          0.0000     2.0000    0.2438        0.1860
# pla_einde_doelstelling_niet_bereikt                                                                 0.0000     3.0000    0.6835        0.3801
# pla_einde_doelstelling_niet_bereikt__nieuw_trajectplan                                              0.0000     7.0000    1.3230        1.0105
# pla_einde_doelstelling_niet_bereikt__overdracht                                                     0.0000     2.0000    0.4131        0.2569
# pla_einde_geplande_einddatum_overschreden_zonder_nader_bericht                                      0.0000     2.0000    0.3518        0.2374
# pla_einde_other                                                                                     0.0000     2.0000    0.2854        0.2049
# pla_einde_uitstroom_anders_dan_volgen_onderwijs__regulier_werk_of_als_zelfstandige                  0.0000     2.0000    0.2520        0.1894
# pla_hist_pla_categorie_doelstelling_1                                                               0.0000     4.0000    0.7877        0.4515
# pla_hist_pla_categorie_doelstelling_10                                                              0.0000     2.0000    0.2996        0.2137
# pla_hist_pla_categorie_doelstelling_11                                                              0.0000     2.0000    0.2283        0.1767
# pla_hist_pla_categorie_doelstelling_16                                                              0.0000     3.0000    0.6046        0.3563
# pla_hist_pla_categorie_doelstelling_2                                                               0.0000     1.0000    0.2117        0.1669
# pla_hist_pla_categorie_doelstelling_27                                                              0.0000     1.0000    0.1460        0.1247
# pla_hist_pla_categorie_doelstelling_3                                                               0.0000     5.0000    1.1400        0.7729
# pla_hist_pla_categorie_doelstelling_4                                                               0.0000     2.0000    0.4025        0.2620
# pla_hist_pla_categorie_doelstelling_5                                                               0.0000     5.0000    1.0212        0.7020
# pla_hist_pla_categorie_doelstelling_6                                                               0.0000     3.0000    0.6278        0.3692
# pla_hist_pla_categorie_doelstelling_9                                                               0.0000     2.0000    0.4395        0.2710
# pla_hist_pla_categorie_doelstelling_other                                                           0.0000     2.0000    0.3126        0.2192
# pla_historie_maatschappelijke_inspanning                                                            0.0000     1.0000    0.4597        0.2484
# pla_historie_ontwikkeling                                                                           0.0000     1.0000    0.6138        0.2371
# pla_historie_other                                                                                  0.0000     1.0000    0.2497        0.1874
# pla_historie_werk                                                                                   0.0000     1.0000    0.8002        0.1599
# pla_historie_werk_en_inburgering                                                                    0.0000     1.0000    0.0784        0.0723
# pla_ondertekeningen_actueel                                                                         0.0000     3.0000    0.4941        0.3109
# pla_ondertekeningen_historie                                                                        0.0000    11.0000    2.5991        3.3027
# relatie_kind_basisschool_kind                                                                       0.0000     2.0000    0.3486        0.2358
# relatie_kind_heeft_kinderen                                                                         0.0000     1.0000    0.3533        0.2285
# relatie_kind_huidige_aantal                                                                         0.0000     4.0000    0.8304        0.5475
# relatie_kind_jongvolwassen                                                                          0.0000     4.0000    0.7446        0.4480
# relatie_kind_leeftijd_verschil_ouder_eerste_kind                                                    0.0000    46.0000   14.4577      102.1002
# relatie_kind_tiener                                                                                 0.0000     2.0000    0.3382        0.2327
# relatie_kind_volwassen                                                                              0.0000     2.0000    0.3832        0.2468
# relatie_overig_actueel_vorm__gemachtigde                                                            0.0000     2.0000    0.1965        0.1581
# relatie_overig_actueel_vorm__kostendeler                                                            0.0000     4.0000    0.8376        0.5484
# relatie_overig_actueel_vorm__onderhoudsplichtige                                                    0.0000     2.0000    0.2529        0.1896
# relatie_overig_actueel_vorm__ouders_verzorgers                                                      0.0000     1.0000    0.1107        0.0985
# relatie_overig_actueel_vorm_other                                                                   0.0000     2.0000    0.2112        0.1669
# relatie_overig_bewindvoerder                                                                        0.0000     1.0000    0.0095        0.0094
# relatie_overig_historie_vorm__andere_inwonende                                                      0.0000     3.0000    0.5827        0.3534
# relatie_overig_historie_vorm__gemachtigde                                                           0.0000     2.0000    0.3967        0.2544
# relatie_overig_historie_vorm__kostendeler                                                           0.0000     6.0000    1.3849        1.1721
# relatie_overig_historie_vorm__onderhoudsplichtige                                                   0.0000     3.0000    0.4792        0.2909
# relatie_overig_kostendeler                                                                          0.0000     1.0000    0.2491        0.1871
# relatie_partner_aantal_partner___partner__gehuwd_                                                   0.0000     2.0000    0.2224        0.1736
# relatie_partner_aantal_partner___partner__ongehuwd_                                                 0.0000     1.0000    0.0771        0.0712
# relatie_partner_huidige_partner___partner__gehuwd_                                                  0.0000     1.0000    0.0530        0.0502
# relatie_partner_totaal_dagen_partner                                                                0.0000  8736.0000 1599.3035  1461169.3750
# typering_aantal                                                                                     0.0000     4.0000    1.2187        0.4736
# typering_dagen_som                                                                             -10480.0000 17082.0000 2175.7166 10066634.0000
# typering_hist_aantal                                                                                1.0000     5.0000    1.6735        0.5872
# typering_hist_inburgeringsbehoeftig                                                                 0.0000     1.0000    0.0068        0.0068
# typering_hist_ind                                                                                   1.0000     1.0000    1.0000        0.0000
# typering_hist_sector_zorg                                                                           0.0000     1.0000    0.0104        0.0103
# typering_ind                                                                                        0.0000     1.0000    0.6813        0.2171
# typering_indicatie_geheime_gegevens                                                                 0.0000     1.0000    0.0652        0.0609
# typering_other                                                                                      0.0000     2.0000    0.4223        0.2589
# typering_transport__logistiek___tuinbouw                                                            0.0000     1.0000    0.0163        0.0160
# typering_zorg__schoonmaak___welzijn                                                                 0.0000     1.0000    0.0068        0.0068

# %%
def get_sensitive_columns_regex(all_columns):
    cols_to_drop = []
    
    sensitive_patterns = [
        r"^adres",             
        r"^persoon_geslacht", # gender
        r"^persoon_leeftijd", # age
        r"^relatie",           
        r"taal", # language 
        r"inburgering", 
        r"nationaliteit",
        r"schrijven0",
        r"schrijven1",
        r"schrijven2",
        r"schrijven3",
        r"schrijvenfalse",
        r"spreken1",
        r"spreken2",
        r"spreken3",
        r"lezen3",
        r"lezen4",
        r"begrijpen3"
        
    ]
    
    combined_pattern = "|".join(sensitive_patterns)
    
    for col in all_columns:
        if re.search(combined_pattern, col, re.IGNORECASE):
            cols_to_drop.append(col)
            
    return cols_to_drop

all_cols = X_train.columns.tolist()
cols_to_drop_names = get_sensitive_columns_regex(all_cols)
drop_idx = [all_cols.index(c) for c in cols_to_drop_names]
print(cols_to_drop_names)
print("=" * 100)
print(f"Good Model: Dropping {len(cols_to_drop_names)} sensitive features.")
# print(X.dtypes)
# print(X.shape)
# Out:
# ['adres_aantal_brp_adres', 'adres_aantal_verschillende_wijken', 'adres_aantal_verzendadres', 'adres_aantal_woonadres_handmatig', 'adres_dagen_op_adres', 'adres_recentst_onderdeel_rdam', 'adres_recentste_buurt_groot_ijsselmonde', 'adres_recentste_buurt_nieuwe_westen', 'adres_recentste_buurt_other', 'adres_recentste_buurt_oude_noorden', 'adres_recentste_buurt_vreewijk', 'adres_recentste_plaats_other', 'adres_recentste_plaats_rotterdam', 'adres_recentste_wijk_charlois', 'adres_recentste_wijk_delfshaven', 'adres_recentste_wijk_feijenoord', 'adres_recentste_wijk_ijsselmonde', 'adres_recentste_wijk_kralingen_c', 'adres_recentste_wijk_noord', 'adres_recentste_wijk_other', 'adres_recentste_wijk_prins_alexa', 'adres_recentste_wijk_stadscentru', 'adres_unieke_wijk_ratio', 'afspraak_afgelopen_jaar_monitoring_insp__wet_taaleis_na_12_mnd_n_a_v__taa04_____geen_maatregel', 'afspraak_afgelopen_jaar_ontheffing_taaleis', 'afspraak_verzenden_beschikking_i_v_m__niet_voldoen_aan_wet_taaleis', 'belemmering_hist_taal', 'contacten_onderwerp_beoordelen_taaleis', 'contacten_onderwerp_boolean_beoordelen_taaleis', 'contacten_onderwerp_boolean_taaleis___voldoet', 'persoon_geslacht_vrouw', 'persoon_leeftijd_bij_onderzoek', 'persoonlijke_eigenschappen_dagen_sinds_taaleis', 'persoonlijke_eigenschappen_nl_begrijpen3', 'persoonlijke_eigenschappen_nl_lezen3', 'persoonlijke_eigenschappen_nl_lezen4', 'persoonlijke_eigenschappen_nl_schrijven0', 'persoonlijke_eigenschappen_nl_schrijven1', 'persoonlijke_eigenschappen_nl_schrijven2', 'persoonlijke_eigenschappen_nl_schrijven3', 'persoonlijke_eigenschappen_nl_schrijvenfalse', 'persoonlijke_eigenschappen_nl_spreken1', 'persoonlijke_eigenschappen_nl_spreken2', 'persoonlijke_eigenschappen_nl_spreken3', 'persoonlijke_eigenschappen_spreektaal', 'persoonlijke_eigenschappen_spreektaal_anders', 'persoonlijke_eigenschappen_taaleis_schrijfv_ok', 'persoonlijke_eigenschappen_taaleis_voldaan', 'pla_historie_werk_en_inburgering', 'relatie_kind_basisschool_kind', 'relatie_kind_heeft_kinderen', 'relatie_kind_huidige_aantal', 'relatie_kind_jongvolwassen', 'relatie_kind_leeftijd_verschil_ouder_eerste_kind', 'relatie_kind_tiener', 'relatie_kind_volwassen', 'relatie_overig_actueel_vorm__gemachtigde', 'relatie_overig_actueel_vorm__kostendeler', 'relatie_overig_actueel_vorm__onderhoudsplichtige', 'relatie_overig_actueel_vorm__ouders_verzorgers', 'relatie_overig_actueel_vorm_other', 'relatie_overig_bewindvoerder', 'relatie_overig_historie_vorm__andere_inwonende', 'relatie_overig_historie_vorm__gemachtigde', 'relatie_overig_historie_vorm__kostendeler', 'relatie_overig_historie_vorm__onderhoudsplichtige', 'relatie_overig_kostendeler', 'relatie_partner_aantal_partner___partner__gehuwd_', 'relatie_partner_aantal_partner___partner__ongehuwd_', 'relatie_partner_huidige_partner___partner__gehuwd_', 'relatie_partner_totaal_dagen_partner', 'typering_hist_inburgeringsbehoeftig']
# ====================================================================================================
# Good Model: Dropping 72 sensitive features.

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('drop_sensitive', 'drop', drop_idx)
    ],
    remainder='passthrough'
)


classifier = HistGradientBoostingClassifier(
    learning_rate=0.2,
    max_iter=1000,
    max_depth=1,
    min_samples_leaf=10,
    l2_regularization=1.0,
    early_stopping=True
)


pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor), 
    ('classification', classifier)
])

# %%
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# Accuracy: 0.9220

# %%
preprocessor_step = pipeline.named_steps['preprocessor']
feature_names_out = preprocessor_step.get_feature_names_out(input_features=X_train.columns)
print(f"remain nums: {len(feature_names_out)}")
print("remain:")
for feature in feature_names_out:
    print(feature)

suspicious_feature = "adres_aantal_woonadres_handmatig"
if suspicious_feature in feature_names_out:
    print(f"{suspicious_feature} still in")
else:
    print(f"{suspicious_feature} out")
# Out:
# remain nums: 243
# remain:
# remainder__afspraak_aanmelding_afgesloten
# remainder__afspraak_aantal_woorden
# remainder__afspraak_afgelopen_jaar_afsprakenplan
# remainder__afspraak_afgelopen_jaar_ontheffing
# remainder__afspraak_afgelopen_jaar_plan_van_aanpak
# remainder__afspraak_afgelopen_jaar_signaal_voor_medewerker
# remainder__afspraak_afgelopen_jaar_vervolgmeting_matchbaarheid_werkzoekende_klant
# remainder__afspraak_afgelopen_jaar_voortgang_aanmelding_en_deelname
# remainder__afspraak_afsprakenplan
# remainder__afspraak_controle_aankondiging_maatregel
# remainder__afspraak_controle_verwijzing
# remainder__afspraak_deelname_compleet_uit_webapplicatie
# remainder__afspraak_galo_gesprek
# remainder__afspraak_gespr__einde_zoekt___galo_gesprek_
# remainder__afspraak_inspanningsperiode
# remainder__afspraak_laatstejaar_aantal_woorden
# remainder__afspraak_laatstejaar_resultaat_ingevuld
# remainder__afspraak_laatstejaar_resultaat_ingevuld_uniek
# remainder__afspraak_other
# remainder__afspraak_participatietrede_vervolgmeting
# remainder__afspraak_resultaat_ingevuld_uniek
# remainder__afspraak_signaal_van_aanbieder
# remainder__afspraak_signaal_voor_medewerker
# remainder__afspraak_toevoegen_inschrijving_uwvwb
# remainder__afspraak_vervolgmeting_matchbaarheid_werkzoekende_klant
# remainder__afspraak_voortgangsgesprek
# remainder__belemmering_aantal_huidig
# remainder__belemmering_dagen_financiele_problemen
# remainder__belemmering_dagen_lichamelijke_problematiek
# remainder__belemmering_dagen_psychische_problemen
# remainder__belemmering_financiele_problemen
# remainder__belemmering_hist_lichamelijke_problematiek
# remainder__belemmering_hist_psychische_problemen
# remainder__belemmering_hist_stabiele_mix__sz____dagbesteding_werk
# remainder__belemmering_hist_verslavingsproblematiek
# remainder__belemmering_ind
# remainder__belemmering_ind_hist
# remainder__belemmering_niet_computervaardig
# remainder__belemmering_psychische_problemen
# remainder__belemmering_woonsituatie
# remainder__beschikbaarheid_aantal_historie_afwijkend_wegens_medische_omstandigheden
# remainder__beschikbaarheid_aantal_historie_afwijkend_wegens_sociaal_maatschappelijke_situatie
# remainder__beschikbaarheid_huidig_afwijkend_wegens_medische_omstandigheden
# remainder__beschikbaarheid_huidig_bekend
# remainder__beschikbaarheid_recent_afwijkend_wegens_medische_omstandigheden
# remainder__beschikbaarheid_recent_afwijkend_wegens_sociaal_maatschappelijke_situatie
# remainder__competentie_aansturen
# remainder__competentie_analyseren
# remainder__competentie_ethisch_en_integer_handelen
# remainder__competentie_formuleren_en_rapporteren
# remainder__competentie_gedrevenheid_en_ambitie_tonen
# remainder__competentie_instructies_en_procedures_opvolgen
# remainder__competentie_kwaliteit_leveren
# remainder__competentie_leren
# remainder__competentie_materialen_en_middelen_inzetten
# remainder__competentie_met_druk_en_tegenslag_omgaan
# remainder__competentie_omgaan_met_verandering_en_aanpassen
# remainder__competentie_onderzoeken
# remainder__competentie_op_de_behoeften_en_verwachtingen_van_de__klant__richten
# remainder__competentie_other
# remainder__competentie_overtuigen_en_beïnvloeden
# remainder__competentie_plannen_en_organiseren
# remainder__competentie_samenwerken_en_overleggen
# remainder__competentie_vakdeskundigheid_toepassen
# remainder__contacten_onderwerp__arbeids_motivatie
# remainder__contacten_onderwerp__pre__intake
# remainder__contacten_onderwerp__werk_intake
# remainder__contacten_onderwerp_arbeidsdiagnose_dariuz
# remainder__contacten_onderwerp_boolean__arbeids_motivatie
# remainder__contacten_onderwerp_boolean__pre__intake
# remainder__contacten_onderwerp_boolean__werk_intake
# remainder__contacten_onderwerp_boolean_contact_derden
# remainder__contacten_onderwerp_boolean_contact_met_aanbieder
# remainder__contacten_onderwerp_boolean_diagnosegesprek
# remainder__contacten_onderwerp_boolean_documenten__innemen_
# remainder__contacten_onderwerp_boolean_documenttype__cv_
# remainder__contacten_onderwerp_boolean_documenttype__diploma_s_en_certificaten_
# remainder__contacten_onderwerp_boolean_documenttype__overeenkomst_
# remainder__contacten_onderwerp_boolean_financiële_situatie
# remainder__contacten_onderwerp_boolean_groepsbijeenkomst
# remainder__contacten_onderwerp_boolean_inkomen
# remainder__contacten_onderwerp_boolean_maatregel_overweging
# remainder__contacten_onderwerp_boolean_match___werk
# remainder__contacten_onderwerp_boolean_matching
# remainder__contacten_onderwerp_boolean_motivatie
# remainder__contacten_onderwerp_boolean_mutatie
# remainder__contacten_onderwerp_boolean_no_show
# remainder__contacten_onderwerp_boolean_overige
# remainder__contacten_onderwerp_boolean_overleg_met_inkomen
# remainder__contacten_onderwerp_boolean_scholing
# remainder__contacten_onderwerp_boolean_sollicitatie
# remainder__contacten_onderwerp_boolean_terugbelverzoek
# remainder__contacten_onderwerp_boolean_traject
# remainder__contacten_onderwerp_boolean_uitnodiging
# remainder__contacten_onderwerp_boolean_ziek__of_afmelding
# remainder__contacten_onderwerp_boolean_zorg
# remainder__contacten_onderwerp_contact_derden
# remainder__contacten_onderwerp_contact_met_aanbieder
# remainder__contacten_onderwerp_diagnosegesprek
# remainder__contacten_onderwerp_documenten__innemen_
# remainder__contacten_onderwerp_documenttype__cv_
# remainder__contacten_onderwerp_documenttype__overeenkomst_
# remainder__contacten_onderwerp_financiële_situatie
# remainder__contacten_onderwerp_groepsbijeenkomst
# remainder__contacten_onderwerp_inkomen
# remainder__contacten_onderwerp_inname_aanvraag
# remainder__contacten_onderwerp_inspanningstoets
# remainder__contacten_onderwerp_maatregel_overweging
# remainder__contacten_onderwerp_matching
# remainder__contacten_onderwerp_mutatie
# remainder__contacten_onderwerp_no_show
# remainder__contacten_onderwerp_overige
# remainder__contacten_onderwerp_overleg_met_inkomen
# remainder__contacten_onderwerp_quickscan
# remainder__contacten_onderwerp_scholing
# remainder__contacten_onderwerp_screening
# remainder__contacten_onderwerp_terugbelverzoek
# remainder__contacten_onderwerp_traject
# remainder__contacten_onderwerp_uitnodiging
# remainder__contacten_onderwerp_vakantie
# remainder__contacten_onderwerp_werkintake__niet_verschenen
# remainder__contacten_onderwerp_ziek__of_afmelding
# remainder__contacten_onderwerp_zorg
# remainder__contacten_soort_afgelopenjaar_anders
# remainder__contacten_soort_afgelopenjaar_document__inkomend_
# remainder__contacten_soort_afgelopenjaar_document__uitgaand_
# remainder__contacten_soort_afgelopenjaar_e_mail__inkomend_
# remainder__contacten_soort_afgelopenjaar_e_mail__uitgaand_
# remainder__contacten_soort_afgelopenjaar_gesprek
# remainder__contacten_soort_afgelopenjaar_gesprek_op_locatie
# remainder__contacten_soort_afgelopenjaar_rapportage_rib
# remainder__contacten_soort_afgelopenjaar_telefoontje__inkomend_
# remainder__contacten_soort_afgelopenjaar_telefoontje__uitgaand_
# remainder__contacten_soort_anders
# remainder__contacten_soort_document__inkomend_
# remainder__contacten_soort_document__uitgaand_
# remainder__contacten_soort_e_mail__inkomend_
# remainder__contacten_soort_e_mail__uitgaand_
# remainder__contacten_soort_gesprek_op_locatie
# remainder__contacten_soort_groepsbijeenkomsten
# remainder__contacten_soort_rapportage_deelname
# remainder__contacten_soort_rapportage_rib
# remainder__contacten_soort_telefoontje__inkomend_
# remainder__contacten_soort_telefoontje__uitgaand_
# remainder__deelname_act_actueel_projecten_uniek
# remainder__deelname_act_hist_projecten_niet_gestart
# remainder__deelname_act_reintegratieladder_ondersteunende_instrumenten
# remainder__deelname_act_reintegratieladder_werk_re_integratie
# remainder__instrument_aantal_laatstejaar
# remainder__instrument_ladder_historie_activering
# remainder__instrument_ladder_historie_other
# remainder__instrument_ladder_huidig_activering
# remainder__instrument_ladder_huidig_other
# remainder__instrument_ladder_huidig_werk_re_integratie
# remainder__instrument_reden_beeindiging_historie_centrale_actie_wigo4it
# remainder__instrument_reden_beeindiging_historie_diagnose_gesteld
# remainder__instrument_reden_beeindiging_historie_direct_matchbaar
# remainder__instrument_reden_beeindiging_historie_doelstelling_bereikt__geen_uitstroom
# remainder__instrument_reden_beeindiging_historie_doelstelling_bereikt__uitstroom_naar_regulier_werk
# remainder__instrument_reden_beeindiging_historie_doelstelling_bereikt__uitstroom_overig
# remainder__instrument_reden_beeindiging_historie_doelstelling_niet_bereikt__geen_uitstroom
# remainder__instrument_reden_beeindiging_historie_niet_matchbaar
# remainder__instrument_reden_beeindiging_historie_niet_succesvol
# remainder__instrument_reden_beeindiging_historie_niet_succesvol__reden_bij_werkzoekende
# remainder__instrument_reden_beeindiging_historie_op_termijn_matchbaar
# remainder__instrument_reden_beeindiging_historie_other
# remainder__instrument_reden_beeindiging_historie_overdracht_naar_mo
# remainder__instrument_reden_beeindiging_historie_overdracht_naar_prematching
# remainder__instrument_reden_beeindiging_historie_overdracht_naar_regulier_team_iwpm
# remainder__instrument_reden_beeindiging_historie_overdracht_succesvol
# remainder__instrument_reden_beeindiging_historie_succesvol
# remainder__instrument_reden_beeindiging_historie_succesvol__doelstelling_bereikt
# remainder__instrument_reden_beeindiging_historie_uitval__aanbod_niet_langer_zinvol_volgens_gemeente
# remainder__instrument_reden_beeindiging_historie_uitval__klant_wz__ziet_af_van_aanbod
# remainder__ontheffing_actueel_ind
# remainder__ontheffing_dagen_hist_mean
# remainder__ontheffing_dagen_hist_vanwege_uw_medische_omstandigheden
# remainder__ontheffing_hist_ind
# remainder__ontheffing_reden_hist_medische_gronden
# remainder__ontheffing_reden_hist_other
# remainder__ontheffing_reden_hist_sociale_gronden
# remainder__ontheffing_reden_hist_tijdelijke_ontheffing_arbeidsverpl__en_tegenprestatie
# remainder__ontheffing_reden_hist_tijdelijke_ontheffing_arbeidsverplichtingen
# remainder__ontheffing_reden_hist_vanwege_uw_sociaal_maatschappelijke_situatie
# remainder__ontheffing_reden_tijdelijke_ontheffing_arbeidsverpl__en_tegenprestatie
# remainder__persoonlijke_eigenschappen_communicatie_opm
# remainder__persoonlijke_eigenschappen_dagen_sinds_opvoer
# remainder__persoonlijke_eigenschappen_doorzettingsvermogen_opm
# remainder__persoonlijke_eigenschappen_flexibiliteit_opm
# remainder__persoonlijke_eigenschappen_hobbies_sport
# remainder__persoonlijke_eigenschappen_houding_opm
# remainder__persoonlijke_eigenschappen_ind_activering_traject
# remainder__persoonlijke_eigenschappen_ind_buiten_kantoortijden
# remainder__persoonlijke_eigenschappen_ind_regulier_arbeidsritme
# remainder__persoonlijke_eigenschappen_initiatief_opm
# remainder__persoonlijke_eigenschappen_leergierigheid_opm
# remainder__persoonlijke_eigenschappen_motivatie_opm
# remainder__persoonlijke_eigenschappen_opstelling
# remainder__persoonlijke_eigenschappen_overige_opmerkingen
# remainder__persoonlijke_eigenschappen_presentatie_opm
# remainder__persoonlijke_eigenschappen_uiterlijke_verzorging_opm
# remainder__persoonlijke_eigenschappen_uitstroom_verw_vlgs_klant
# remainder__persoonlijke_eigenschappen_uitstroom_verw_vlgs_km
# remainder__persoonlijke_eigenschappen_zelfstandigheid_opm
# remainder__pla_actueel_pla_categorie_doelstelling_16
# remainder__pla_actueel_pla_categorie_doelstelling_9
# remainder__pla_einde_doelstelling_bereikt
# remainder__pla_einde_doelstelling_bereikt__nieuw_trajectplan
# remainder__pla_einde_doelstelling_bereikt__overdracht
# remainder__pla_einde_doelstelling_niet_bereikt
# remainder__pla_einde_doelstelling_niet_bereikt__nieuw_trajectplan
# remainder__pla_einde_doelstelling_niet_bereikt__overdracht
# remainder__pla_einde_geplande_einddatum_overschreden_zonder_nader_bericht
# remainder__pla_einde_other
# remainder__pla_einde_uitstroom_anders_dan_volgen_onderwijs__regulier_werk_of_als_zelfstandige
# remainder__pla_hist_pla_categorie_doelstelling_1
# remainder__pla_hist_pla_categorie_doelstelling_10
# remainder__pla_hist_pla_categorie_doelstelling_11
# remainder__pla_hist_pla_categorie_doelstelling_16
# remainder__pla_hist_pla_categorie_doelstelling_2
# remainder__pla_hist_pla_categorie_doelstelling_27
# remainder__pla_hist_pla_categorie_doelstelling_3
# remainder__pla_hist_pla_categorie_doelstelling_4
# remainder__pla_hist_pla_categorie_doelstelling_5
# remainder__pla_hist_pla_categorie_doelstelling_6
# remainder__pla_hist_pla_categorie_doelstelling_9
# remainder__pla_hist_pla_categorie_doelstelling_other
# remainder__pla_historie_maatschappelijke_inspanning
# remainder__pla_historie_ontwikkeling
# remainder__pla_historie_other
# remainder__pla_historie_werk
# remainder__pla_ondertekeningen_actueel
# remainder__pla_ondertekeningen_historie
# remainder__typering_aantal
# remainder__typering_dagen_som
# remainder__typering_hist_aantal
# remainder__typering_hist_ind
# remainder__typering_hist_sector_zorg
# remainder__typering_ind
# remainder__typering_indicatie_geheime_gegevens
# remainder__typering_other
# remainder__typering_transport__logistiek___tuinbouw
# remainder__typering_zorg__schoonmaak___welzijn
# adres_aantal_woonadres_handmatig out

# %%
initial_type = [('X', FloatTensorType((None, X.shape[1])))]
onnx_model = convert_sklearn(
    pipeline, 
    initial_types=initial_type,
    target_opset=12
)
sess = rt.InferenceSession(onnx_model.SerializeToString())
y_pred_onnx = sess.run(None, {'X': X_test.values.astype(np.float32)})

accuracy_onnx_model = accuracy_score(y_test, y_pred_onnx[0])
print('Accuracy of the ONNX Good Model: ', accuracy_onnx_model)
# Out:
# Accuracy of the ONNX Good Model:  0.9219820769636268

# %%
onnx.save(onnx_model, "model/good_model.onnx")
new_session = rt.InferenceSession("model/good_model.onnx")
y_pred_onnx2 = new_session.run(None, {'X': X_test.values.astype(np.float32)})
print('Model re-loaded successfully. Accuracy verified.')
# Out:
# Model re-loaded successfully. Accuracy verified.
